# %% [markdown]
# # Title:
# # Are there correlations between socioeconomic topics and deaths caused by Corona virus?

# %% [markdown]
# ##    1. Introduction to the analysis.

# %% [markdown]
# In this study we are interested in finding possible correlations between the data from COVID-19 distribution (number of infected people, deaths and recovered per country). Having a correlation, and even not observing a correlation is an important observation and a step ahead in understanding the situation of different countries during the times of the Pandemics. For our analysis, we focused on the data from the EU countries.

# %% [markdown]
# ##  2. Data used

# %% [markdown]
# 2. Data sources and methods of extracting data are as follows:
# <br>
# API - connection:
# <br>
#     → EUROSTAT (Statistical Office of the European Union)
# <br>
# API - download of json-files:
# <br>
#     → WHO (World Health Organization)
# <br>
# Direct download of csv-files:
# <br>
#     → Kaggle, Robert-Koch-Institut
# <br>
# Handmade table:
# <br>
#     → Human development index (HDI)

# %% [markdown]
# ## 3. Questions to answer:

# %% [markdown]
# Are there correlations between socioeconomic topics and deaths caused by Corona virus in Europe?
#
# In some cases there are correlations between the the numbers of the COVID-19 and the studies factors (e.g. high number of hotel usage in a country or high number of air transport of passengers). In other cases, no correlation is observed.

# %% [markdown]
# ##  4. Insights derived from the analysis:

# %% [markdown]
# The analysis at this level shows that there is no direct correlation between the socioeconomic factors and covid-19 infection cases. This makes sense as well, since the number of infections or deaths are affected by other important factors as well (e.g start of quarantine situation in a country or detecting the first infected cases as soon as possible). This means, even if a country has high scores such as high HDI-scores (http://hdr.undp.org/en/content/human-development-index-hdi), it is possible to be affected dramatically by viruses such as COVID-19, due to lack of preparations for pandemics.

# %% [markdown]
# ## 5. Possible further questions and improvements:

# %% [markdown]
# Further Analysis of other factors (e.g. usage of
#
#
# Table of links:
# <br>
# EUROSTAT
# <br>
# https://ec.europa.eu/eurostat/web/json-and-unicode-web-services/getting-started/rest-request
# <br>
# WHO
# <br>
# https://documenter.getpostman.com/view/10808728/SzS8rjbc?version=latest#81415d42-eb53-4a85-8484-42d2349debfe
# <br>
# HDI
# <br>
# http://hdr.undp.org/en/content/human-development-index-hdi
# <br>
# RKI
# <br>
# https://npgeo-corona-npgeo-de.hub.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0
# <br>

# %% [markdown]
# Slides of our presentation is found under the link:
# <br>
# https://github.com/ThomasBentler/DATA-THIEVES-COVID19/blob/master/Presentation_ProjectDataThief_Coronavirus_FINAL.pdf

# %% [markdown]
# ## 6. Comparision of socio-economic Factors with Covid-19 Data, Step by Step

# %% [markdown]
# ## 6.1. Accessing COVID-19 Data

# %%
import pandas as pd
import requests
import json
#from flatten_json import flatten 
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import datetime
import re
import requests
import bs4
from IPython.display import display, HTML
import numpy as np

# %%
# Plot Covid data from WHO
# Covid data was downloaded with:
# curl --location --request GET 'https://api.covid19api.com/all' > covidwho.json

# %%
df_who = pd.read_json (r'Data/novel-corona-virus-2019-dataset/covidwho.json')

# %%
df_who.head()
# Out:
#        Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 0  Afghanistan          AF  33.94  67.71          0       0          0
# 1  Afghanistan          AF  33.94  67.71          0       0          0
# 2  Afghanistan          AF  33.94  67.71          0       0          0
# 3  Afghanistan          AF  33.94  67.71          0       0          0
# 4  Afghanistan          AF  33.94  67.71          0       0          0
#
#    Active                      Date                            LocationID  \
# 0       0 2020-01-22 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 1       0 2020-01-23 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 2       0 2020-01-24 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 3       0 2020-01-25 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 4       0 2020-01-26 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
#
#   Province City CityCode
# 0      NaN  NaN      NaN
# 1      NaN  NaN      NaN
# 2      NaN  NaN      NaN
# 3      NaN  NaN      NaN
# 4      NaN  NaN      NaN

# %%
df_who_Germany = df_who[df_who['Country'] =="Germany"]
df_who_Germany
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 9629  Germany          DE  51.17  10.45          0       0          0       0
# 9630  Germany          DE  51.17  10.45          0       0          0       0
# 9631  Germany          DE  51.17  10.45          0       0          0       0
# 9632  Germany          DE  51.17  10.45          0       0          0       0
# 9633  Germany          DE  51.17  10.45          0       0          0       0
# ...       ...         ...    ...    ...        ...     ...        ...     ...
# 9701  Germany          DE  51.17  10.45      91159    1275      24575       0
# 9702  Germany          DE  51.17  10.45      96092    1444      26400       0
# 9703  Germany          DE  51.17  10.45     100123    1584      28700       0
# 9704  Germany          DE  51.17  10.45     103374    1810      28700       0
# 9705  Germany          DE  51.17  10.45     107663    2016      36081       0
#
#                           Date                            LocationID Province  \
# 9629 2020-01-22 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9630 2020-01-23 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9631 2020-01-24 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9632 2020-01-25 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9633 2020-01-26 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# ...                        ...                                   ...      ...
# 9701 2020-04-03 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9702 2020-04-04 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9703 2020-04-05 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9704 2020-04-06 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9705 2020-04-07 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
#
#      City CityCode
# 9629  NaN      NaN
# 9630  NaN      NaN
# 9631  NaN      NaN
# 9632  NaN      NaN
# 9633  NaN      NaN
# ...   ...      ...
# 9701  NaN      NaN
# 9702  NaN      NaN
# 9703  NaN      NaN
# 9704  NaN      NaN
# 9705  NaN      NaN
#
# [77 rows x 13 columns]

# %%
df_who_Italy = df_who[df_who['Country'] =="Italy"]
df_who_Italy.head()
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 11092   Italy          IT  41.87  12.57          0       0          0       0
# 11093   Italy          IT  41.87  12.57          0       0          0       0
# 11094   Italy          IT  41.87  12.57          0       0          0       0
# 11095   Italy          IT  41.87  12.57          0       0          0       0
# 11096   Italy          IT  41.87  12.57          0       0          0       0
#
#                            Date                            LocationID  \
# 11092 2020-01-22 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11093 2020-01-23 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11094 2020-01-24 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11095 2020-01-25 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11096 2020-01-26 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
#
#       Province City CityCode
# 11092      NaN  NaN      NaN
# 11093      NaN  NaN      NaN
# 11094      NaN  NaN      NaN
# 11095      NaN  NaN      NaN
# 11096      NaN  NaN      NaN

# %%
df_who_Spain = df_who[df_who['Country'] =="Spain"]
df_who_Spain.head()
# Out:
#       Country CountryCode    Lat   Lon  Confirmed  Deaths  Recovered  Active  \
# 16870   Spain          ES  40.46 -3.75          0       0          0       0
# 16871   Spain          ES  40.46 -3.75          0       0          0       0
# 16872   Spain          ES  40.46 -3.75          0       0          0       0
# 16873   Spain          ES  40.46 -3.75          0       0          0       0
# 16874   Spain          ES  40.46 -3.75          0       0          0       0
#
#                            Date                            LocationID  \
# 16870 2020-01-22 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16871 2020-01-23 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16872 2020-01-24 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16873 2020-01-25 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16874 2020-01-26 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
#
#       Province City CityCode
# 16870      NaN  NaN      NaN
# 16871      NaN  NaN      NaN
# 16872      NaN  NaN      NaN
# 16873      NaN  NaN      NaN
# 16874      NaN  NaN      NaN

# %% [markdown]
# 6.1.1 Pre-Study: Plotting the Covid 19 figures of various country's development over time side by side

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.plot(df_who_Germany['Date'], df_who_Germany['Confirmed'], zorder=1 , color="g",label = "Germany")
plt.plot(df_who_Italy['Date'], df_who_Italy['Confirmed'], zorder=2 , color="b" , label = "Italy")
plt.plot(df_who_Spain['Date'], df_who_Spain['Confirmed'], zorder=3 , color="r", label = "Spain")
ax.set_title("Confirmed")

plt.legend(loc="upper left");
# Out:
# /home/bita/anaconda3/envs/backpack1/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.plot(df_who_Germany['Date'], df_who_Germany['Deaths'], zorder=1 , color="g",label = "Germany")
plt.plot(df_who_Italy['Date'], df_who_Italy['Deaths'], zorder=2 , color="b", label = "Italy")
plt.plot(df_who_Spain['Date'], df_who_Spain['Deaths'], zorder=3 , color="r", label = "Spain")
ax.set_title("Deaths")

plt.legend(loc="upper left");
plt.savefig("Figures/WHO-Confirmed.png") # save as png

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.plot(df_who_Germany['Date'], df_who_Germany['Recovered'], zorder=1 , color="g",label = "Germany")
plt.plot(df_who_Italy['Date'], df_who_Italy['Recovered'], zorder=2 , color="b", label = "Italy")
plt.plot(df_who_Spain['Date'], df_who_Spain['Recovered'], zorder=3 , color="r", label = "Spain")
ax.set_title("Recovered")

plt.legend(loc="upper left");
plt.savefig("Figures/WHO-Deaths.png") # save as png

# %% [markdown]
# ## 6.2. Covid-19 and HDI-Index

# %%
# Selected Countries for the Analysis:
#from HDI Index
countries_sel = ["Norway", "Ireland", "Germany","Sweden","Netherlands","Denmark","Finland","United Kingdo",
                 "Belgium","Austria", "Luxembourg","Sloenia","Spain","France","Czechia","Malta","Estonia","Italy","Cyprus","Greece",
    "Lithuania","Poland","Slovakia","Latvia","Portugal","Hungary","Croatia","Bulgaria","Romania"]
plt.savefig("Figures/WHO-Recovered.png") # save as png

# %%
# Import HDI score from Jens:

hdi_score = pd.read_csv('Data/CSV-Files/From_HDI/data_HDI_EU.csv')

# %%
# Plot HDI score by Jens:

#hdi_score.set_index("geo")
fig, ax = plt.subplots(figsize = (13,8))

ax.bar(hdi_score["geo"],
       hdi_score["HDI_score_2017"],
       color = 'y');
ax.tick_params(labelrotation=90)
ax.set_title("HDI score 2017")
ax.set_ylabel("HDI")
ax.set_frame_on(False)

plt.axhline(y=1, xmin=0.0, xmax=1, label = "high: 0.8-1", linewidth=1, color = 'g', );
plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'b', );
plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );

plt.legend(loc="lower center");

# %%
# Extract data from the last Date (7th of April)

df_who_lastday = df_who[df_who['Date'] =="2020-04-07 00:00:00+00:00"]
df_who_lastday.head()
# Out:
#          Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 76   Afghanistan          AF  33.94  67.71        423      14         18
# 153      Albania          AL  41.15  20.17        383      22        131
# 230      Algeria          DZ  28.03   1.66       1468     193        113
# 307      Andorra          AD  42.55   1.60        545      22         39
# 384       Angola          AO -11.20  17.87         17       2          2
#
#      Active                      Date                            LocationID  \
# 76        0 2020-04-07 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 153       0 2020-04-07 00:00:00+00:00  07ef547a-c2a5-4279-8f24-0295e9c7fe7a
# 230       0 2020-04-07 00:00:00+00:00  e6bec38b-4eae-4ce4-bbaf-69f532c1bd5f
# 307       0 2020-04-07 00:00:00+00:00  9f52c049-2008-45d8-8f86-7c009e015d17
# 384       0 2020-04-07 00:00:00+00:00  8bba7786-aabb-423a-97a1-7140fa6dfe19
#
#     Province City CityCode
# 76       NaN  NaN      NaN
# 153      NaN  NaN      NaN
# 230      NaN  NaN      NaN
# 307      NaN  NaN      NaN
# 384      NaN  NaN      NaN

# %%
#select countries from the list of countries (Countries that we like to study)

df_who_lastday_sel_none_unique = df_who_lastday[df_who_lastday.Country.str.contains('|'.join(countries_sel))]
df_who_lastday_sel_none_unique.head()
# Out:
#        Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 1308   Austria          AT  47.52  14.55      12639     243       4046
# 1847   Belgium          BE  50.50   4.47      22194    2035       4157
# 2540  Bulgaria          BG  42.73  25.49        577      23         42
# 7237   Croatia          HR  45.10  15.20       1282      18        167
# 7391    Cyprus          CY  35.13  33.43        494       9         47
#
#       Active                      Date                            LocationID  \
# 1308       0 2020-04-07 00:00:00+00:00  39ca28f2-2ade-49f4-9516-e9b8cd8f48e6
# 1847       0 2020-04-07 00:00:00+00:00  1c49b6bb-1b83-4fe3-b536-da1731fe6953
# 2540       0 2020-04-07 00:00:00+00:00  de959b36-8cda-4645-9675-acc067f8fa56
# 7237       0 2020-04-07 00:00:00+00:00  b43d07be-a945-4525-91a2-b1fb47d46c2f
# 7391       0 2020-04-07 00:00:00+00:00  024ac3a0-b462-4db7-a25f-3774f3c34aaa
#
#      Province City CityCode
# 1308      NaN  NaN      NaN
# 1847      NaN  NaN      NaN
# 2540      NaN  NaN      NaN
# 7237      NaN  NaN      NaN
# 7391      NaN  NaN      NaN

# %%
# The list above had multiple values for e.g France (e.g. Reunio). We discard those Provinces...
df_who_lastday_sel = df_who_lastday_sel_none_unique[df_who_lastday_sel_none_unique['Province'].isna()]
df_who_lastday_sel
# Out:
#               Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 1308          Austria          AT  47.52  14.55      12639     243       4046
# 1847          Belgium          BE  50.50   4.47      22194    2035       4157
# 2540         Bulgaria          BG  42.73  25.49        577      23         42
# 7237          Croatia          HR  45.10  15.20       1282      18        167
# 7391           Cyprus          CY  35.13  33.43        494       9         47
# 7697          Denmark          DK  56.26   9.50       5071     203       1491
# 8392          Estonia          EE  58.60  25.01       1149      21         69
# 8623          Finland          FI  61.92  25.75       2308      34        300
# 9396           France          FR  46.23   2.21     109069   10328      19337
# 9705          Germany          DE  51.17  10.45     107663    2016      36081
# 9859           Greece          GR  39.07  21.82       1832      81        269
# 10552         Hungary          HU  47.16  19.50        817      47         71
# 11014         Ireland          IE  53.41  -8.24       5709     210         25
# 11168           Italy          IT  41.87  12.57     135586   17127      24392
# 11938          Latvia          LV  56.88  24.60        548       2         16
# 12323       Lithuania          LT  55.17  23.88        880      15          8
# 12400      Luxembourg          LU  49.82   6.13       2970      44        500
# 12939           Malta          MT  35.94  14.38        293       0          5
# 14248     Netherlands          NL  52.13   5.29      19580    2101        250
# 14633          Norway          NO  60.47   8.47       6086      89         32
# 15326          Poland          PL  51.92  19.15       4848     129        191
# 15403        Portugal          PT  39.40  -8.22      12442     345        184
# 15634         Romania          RO  45.94  24.97       4417     197        460
# 16638        Slovakia          SK  48.67  19.70        581       2         13
# 16946           Spain          ES  40.46  -3.75     141942   14045      43208
# 17331          Sweden          SE  60.13  18.64       7693     591        205
# 19107  United Kingdom          GB  55.38  -3.44      55242    6159        135
#
#        Active                      Date                            LocationID  \
# 1308        0 2020-04-07 00:00:00+00:00  39ca28f2-2ade-49f4-9516-e9b8cd8f48e6
# 1847        0 2020-04-07 00:00:00+00:00  1c49b6bb-1b83-4fe3-b536-da1731fe6953
# 2540        0 2020-04-07 00:00:00+00:00  de959b36-8cda-4645-9675-acc067f8fa56
# 7237        0 2020-04-07 00:00:00+00:00  b43d07be-a945-4525-91a2-b1fb47d46c2f
# 7391        0 2020-04-07 00:00:00+00:00  024ac3a0-b462-4db7-a25f-3774f3c34aaa
# 7697        0 2020-04-07 00:00:00+00:00  761966af-c2cf-4bd9-a375-2c4198cff021
# 8392        0 2020-04-07 00:00:00+00:00  d255c144-46dc-4320-8265-0060fabcdee0
# 8623        0 2020-04-07 00:00:00+00:00  bc1adb31-d848-4cfd-a898-194fe9376367
# 9396        0 2020-04-07 00:00:00+00:00  c6189b06-e1f8-47c5-b975-0110c1b6e78f
# 9705        0 2020-04-07 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b
# 9859        0 2020-04-07 00:00:00+00:00  70392d48-d54a-4f21-9336-1653fcca137e
# 10552       0 2020-04-07 00:00:00+00:00  86b5483f-a35c-4c17-a34d-c88d5a04b048
# 11014       0 2020-04-07 00:00:00+00:00  9d330a1e-5c20-4205-b20a-88ef0977e936
# 11168       0 2020-04-07 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11938       0 2020-04-07 00:00:00+00:00  759dd379-0fd6-4826-aa12-4f39b4f2ebdd
# 12323       0 2020-04-07 00:00:00+00:00  670e3a25-597e-4fdb-9d6e-239fed120525
# 12400       0 2020-04-07 00:00:00+00:00  e6c04ef0-76af-4322-a1b1-db148ff287b6
# 12939       0 2020-04-07 00:00:00+00:00  03e68e52-4ad5-4b28-873a-13bc654baf3a
# 14248       0 2020-04-07 00:00:00+00:00  4fd2b0ff-7680-4fb5-8d0c-ffd01b49d849
# 14633       0 2020-04-07 00:00:00+00:00  2abc0f85-1950-4d1e-b364-1be2242c1e19
# 15326       0 2020-04-07 00:00:00+00:00  4224d04c-7225-4988-9341-cfc60ac1ec52
# 15403       0 2020-04-07 00:00:00+00:00  993f0da3-ad2e-4699-84fa-b912b3829ee4
# 15634       0 2020-04-07 00:00:00+00:00  487e9392-3fe2-4343-9ca8-37f823fca6b5
# 16638       0 2020-04-07 00:00:00+00:00  62562dc8-23e5-4da5-bdbf-906f3a6d05c5
# 16946       0 2020-04-07 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 17331       0 2020-04-07 00:00:00+00:00  d6e8b61f-589a-4d3b-8d5d-5b01b31d44b6
# 19107       0 2020-04-07 00:00:00+00:00  32aadebc-ff17-40f7-9e6a-1277168074f9
#
#       Province City CityCode
# 1308       NaN  NaN      NaN
# 1847       NaN  NaN      NaN
# 2540       NaN  NaN      NaN
# 7237       NaN  NaN      NaN
# 7391       NaN  NaN      NaN
# 7697       NaN  NaN      NaN
# 8392       NaN  NaN      NaN
# 8623       NaN  NaN      NaN
# 9396       NaN  NaN      NaN
# 9705       NaN  NaN      NaN
# 9859       NaN  NaN      NaN
# 10552      NaN  NaN      NaN
# 11014      NaN  NaN      NaN
# 11168      NaN  NaN      NaN
# 11938      NaN  NaN      NaN
# 12323      NaN  NaN      NaN
# 12400      NaN  NaN      NaN
# 12939      NaN  NaN      NaN
# 14248      NaN  NaN      NaN
# 14633      NaN  NaN      NaN
# 15326      NaN  NaN      NaN
# 15403      NaN  NaN      NaN
# 15634      NaN  NaN      NaN
# 16638      NaN  NaN      NaN
# 16946      NaN  NaN      NaN
# 17331      NaN  NaN      NaN
# 19107      NaN  NaN      NaN

# %%
# Here COVID data was extracted for joining with EUROSTAT data in MYSQL and further plotting of COVID data 
# versus EUROSTAT data by Thomas 
#df_who_lastday_sel.to_csv("WHO7thApril.csv", index=False)

# %%
# rename hdi table's name from geo to Country
hdi_score.rename(columns={'geo':'Country'}, inplace=True)

# %%
# Merge hdi index and death values based on Countries
hdi_combined = pd.merge(hdi_score, df_who_lastday_sel, on="Country")
hdi_combined
# Out:
#            Country  HDI_score_2017 CountryCode    Lat    Lon  Confirmed  \
# 0           Norway           0.954          NO  60.47   8.47       6086
# 1          Ireland           0.942          IE  53.41  -8.24       5709
# 2          Germany           0.939          DE  51.17  10.45     107663
# 3           Sweden           0.937          SE  60.13  18.64       7693
# 4      Netherlands           0.933          NL  52.13   5.29      19580
# 5          Denmark           0.930          DK  56.26   9.50       5071
# 6          Finland           0.925          FI  61.92  25.75       2308
# 7   United Kingdom           0.920          GB  55.38  -3.44      55242
# 8          Belgium           0.919          BE  50.50   4.47      22194
# 9          Austria           0.914          AT  47.52  14.55      12639
# 10      Luxembourg           0.909          LU  49.82   6.13       2970
# 11           Spain           0.893          ES  40.46  -3.75     141942
# 12          France           0.891          FR  46.23   2.21     109069
# 13           Malta           0.885          MT  35.94  14.38        293
# 14         Estonia           0.882          EE  58.60  25.01       1149
# 15           Italy           0.880          IT  41.87  12.57     135586
# 16          Cyprus           0.873          CY  35.13  33.43        494
# 17          Greece           0.870          GR  39.07  21.82       1832
# 18       Lithuania           0.869          LT  55.17  23.88        880
# 19          Poland           0.865          PL  51.92  19.15       4848
# 20        Slovakia           0.857          SK  48.67  19.70        581
# 21          Latvia           0.854          LV  56.88  24.60        548
# 22        Portugal           0.847          PT  39.40  -8.22      12442
# 23         Hungary           0.838          HU  47.16  19.50        817
# 24         Croatia           0.837          HR  45.10  15.20       1282
# 25        Bulgaria           0.813          BG  42.73  25.49        577
# 26         Romania           0.811          RO  45.94  24.97       4417
#
#     Deaths  Recovered  Active                      Date  \
# 0       89         32       0 2020-04-07 00:00:00+00:00
# 1      210         25       0 2020-04-07 00:00:00+00:00
# 2     2016      36081       0 2020-04-07 00:00:00+00:00
# 3      591        205       0 2020-04-07 00:00:00+00:00
# 4     2101        250       0 2020-04-07 00:00:00+00:00
# 5      203       1491       0 2020-04-07 00:00:00+00:00
# 6       34        300       0 2020-04-07 00:00:00+00:00
# 7     6159        135       0 2020-04-07 00:00:00+00:00
# 8     2035       4157       0 2020-04-07 00:00:00+00:00
# 9      243       4046       0 2020-04-07 00:00:00+00:00
# 10      44        500       0 2020-04-07 00:00:00+00:00
# 11   14045      43208       0 2020-04-07 00:00:00+00:00
# 12   10328      19337       0 2020-04-07 00:00:00+00:00
# 13       0          5       0 2020-04-07 00:00:00+00:00
# 14      21         69       0 2020-04-07 00:00:00+00:00
# 15   17127      24392       0 2020-04-07 00:00:00+00:00
# 16       9         47       0 2020-04-07 00:00:00+00:00
# 17      81        269       0 2020-04-07 00:00:00+00:00
# 18      15          8       0 2020-04-07 00:00:00+00:00
# 19     129        191       0 2020-04-07 00:00:00+00:00
# 20       2         13       0 2020-04-07 00:00:00+00:00
# 21       2         16       0 2020-04-07 00:00:00+00:00
# 22     345        184       0 2020-04-07 00:00:00+00:00
# 23      47         71       0 2020-04-07 00:00:00+00:00
# 24      18        167       0 2020-04-07 00:00:00+00:00
# 25      23         42       0 2020-04-07 00:00:00+00:00
# 26     197        460       0 2020-04-07 00:00:00+00:00
#
#                               LocationID Province City CityCode
# 0   2abc0f85-1950-4d1e-b364-1be2242c1e19      NaN  NaN      NaN
# 1   9d330a1e-5c20-4205-b20a-88ef0977e936      NaN  NaN      NaN
# 2   f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN  NaN      NaN
# 3   d6e8b61f-589a-4d3b-8d5d-5b01b31d44b6      NaN  NaN      NaN
# 4   4fd2b0ff-7680-4fb5-8d0c-ffd01b49d849      NaN  NaN      NaN
# 5   761966af-c2cf-4bd9-a375-2c4198cff021      NaN  NaN      NaN
# 6   bc1adb31-d848-4cfd-a898-194fe9376367      NaN  NaN      NaN
# 7   32aadebc-ff17-40f7-9e6a-1277168074f9      NaN  NaN      NaN
# 8   1c49b6bb-1b83-4fe3-b536-da1731fe6953      NaN  NaN      NaN
# 9   39ca28f2-2ade-49f4-9516-e9b8cd8f48e6      NaN  NaN      NaN
# 10  e6c04ef0-76af-4322-a1b1-db148ff287b6      NaN  NaN      NaN
# 11  b4241151-a623-4529-ac08-9ff297410543      NaN  NaN      NaN
# 12  c6189b06-e1f8-47c5-b975-0110c1b6e78f      NaN  NaN      NaN
# 13  03e68e52-4ad5-4b28-873a-13bc654baf3a      NaN  NaN      NaN
# 14  d255c144-46dc-4320-8265-0060fabcdee0      NaN  NaN      NaN
# 15  5bb4a80b-f42d-4622-b55e-bfcc9d24c574      NaN  NaN      NaN
# 16  024ac3a0-b462-4db7-a25f-3774f3c34aaa      NaN  NaN      NaN
# 17  70392d48-d54a-4f21-9336-1653fcca137e      NaN  NaN      NaN
# 18  670e3a25-597e-4fdb-9d6e-239fed120525      NaN  NaN      NaN
# 19  4224d04c-7225-4988-9341-cfc60ac1ec52      NaN  NaN      NaN
# 20  62562dc8-23e5-4da5-bdbf-906f3a6d05c5      NaN  NaN      NaN
# 21  759dd379-0fd6-4826-aa12-4f39b4f2ebdd      NaN  NaN      NaN
# 22  993f0da3-ad2e-4699-84fa-b912b3829ee4      NaN  NaN      NaN
# 23  86b5483f-a35c-4c17-a34d-c88d5a04b048      NaN  NaN      NaN
# 24  b43d07be-a945-4525-91a2-b1fb47d46c2f      NaN  NaN      NaN
# 25  de959b36-8cda-4645-9675-acc067f8fa56      NaN  NaN      NaN
# 26  487e9392-3fe2-4343-9ca8-37f823fca6b5      NaN  NaN      NaN

# %%
## Plot HDI-SCORE versus Covid 19 Death Rates


fig, ax = plt.subplots(figsize = (15,10))


ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax3 = ax.twinx() # Create another axes that shares the same x-axis as ax.


plt.gca().axes.get_yaxis().set_visible(False)


width = 0.4


p1 = hdi_combined.HDI_score_2017.plot(kind='bar', color='y', ax=ax, width=width, position=1,label = 'HDI')
p2 = hdi_combined.Deaths.plot(kind='bar', color='black', ax=ax2, width=width, position=0, label = 'Deaths')


p3 = plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'g', );
p4 = plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );


ax.set_xticklabels(hdi_combined.Country, rotation=90)
ax.set_ylabel('HDI score 2018')
ax2.set_ylabel('Deaths')
#ax.tick_params(labelrotation=90)
ax.set_title("HDI score (2018) vs. no. of deaths")
ax.set_frame_on(False)


ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.91, 0.95), loc=2, borderaxespad=0.);
ax3.legend(bbox_to_anchor=(0.86, 0.91), loc=2, borderaxespad=0.);


plt.savefig("Figures/HDI-Deaths2.png") # save as png

# %%
# The figure shows no correlation between the HDI-Index and the COVID-19 values of number of Deaths.
# This is particularly due to complexity of Pandemics and possibly due to other factors e.g. decision making
# in start of quarantine and finding the first infected cases, which are not considered in HDI-Index

# %%
## Plot HDI-SCORE versus Recovered Cases


fig, ax = plt.subplots(figsize = (15,10))


ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax3 = ax.twinx() # Create another axes that shares the same x-axis as ax.


plt.gca().axes.get_yaxis().set_visible(False)


width = 0.4


p1 = hdi_combined.HDI_score_2017.plot(kind='bar', color='y', ax=ax, width=width, position=1,label = 'HDI')
p2 = hdi_combined.Recovered.plot(kind='bar', color='c', ax=ax2, width=width, position=0, label = 'Recovered')


p3 = plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'g', );
p4 = plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );


ax.set_xticklabels(hdi_combined.Country, rotation=90)
ax.set_ylabel('HDI score 2018')
ax2.set_ylabel('Recovered')
#ax.tick_params(labelrotation=90)
ax.set_title("HDI score (2018) vs. no. of recovered cases")
ax.set_frame_on(False)


ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.89, 0.95), loc=2, borderaxespad=0.);
ax3.legend(bbox_to_anchor=(0.86, 0.91), loc=2, borderaxespad=0.);


plt.savefig("Figures/HDI-Recovered.png") # save as png

# %%
## Plot HDI-SCORE versus Recovered Cases


fig, ax = plt.subplots(figsize = (15,10))


ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax3 = ax.twinx() # Create another axes that shares the same x-axis as ax.


plt.gca().axes.get_yaxis().set_visible(False)


width = 0.4


p1 = hdi_combined.HDI_score_2017.plot(kind='bar', color='y', ax=ax, width=width, position=1,label = 'HDI')
p2 = hdi_combined.Confirmed.plot(kind='bar', color='mediumslateblue', ax=ax2, width=width, position=0, label = 'Confirmed')


p3 = plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'g', );
p4 = plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );


ax.set_xticklabels(hdi_combined.Country, rotation=90)
ax.set_ylabel('HDI score 2018')
ax2.set_ylabel('Confirmed')
#ax.tick_params(labelrotation=90)
ax.set_title("HDI score (2018) vs. no. of confirmed cases")
ax.set_frame_on(False)


ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.89, 0.95), loc=2, borderaxespad=0.);
ax3.legend(bbox_to_anchor=(0.86, 0.91), loc=2, borderaxespad=0.);


plt.savefig("Figures/HDI-Confirmed.png") # save as png

# %% [markdown]
# ## 6.3. Covid-19 and Other Socioeconomic Factors

# %% [markdown]
# 1. Step: We created a new SQL scheme in our local MySQL Database called "newcovid"
# <br>
# 2. Step:  We imported required python libraries below
# <br>
# 3. Step: We established a connection to the newly created MySQL DB "newcovid"

# %%
#import pandas as pd
#import requests
#import json
#from flatten_json import flatten 
#import matplotlib
#from matplotlib import pyplot as plt
#%matplotlib inline

# %%
# establishing a connection to local SPL Database and use secure poassword method "getpass"
#import pymysql
#import getpass
#conn = pymysql.connect(host="localhost",
#                       port=3306,
#                       user="root",
#                       passwd=getpass.getpass(),
#                       db="newcovid")

# %% [markdown]
# Definition of the URL-String components accoring to the Eurostat API REST Request requirements:
# (https://ec.europa.eu/eurostat/web/json-and-unicode-web-services/getting-started/rest-request)
# <br>
#     1) Variable 'Eurostat_base' to be used as URL-base
# <br>
#     2) Dictionary 'Eurostat_dict' with values to be called as second URL-component by identyable keys,
#    which will themselves later serve as names for the respective SQL tables
# <br>
#     3) Empty list 'df_list', which which as an intermediate container lateron will receive the dataframes,
#    once they are created from the JSON-Files, which we receive from the Eurostat API.
# <br>

# %%
Eurostat_base = "http://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/"
Eurostat_dict ={"Eurostat_population_density_2018" : 
                "tps00003?unit=PER_KM2&precision=1&time=2018",
                "Eurostat_air_transport_passengers_2018" : 
                "ttr00012?tra_meas=PAS_CRD&precision=1&tra_cov=TOTAL&schedule=TOT&unit=PAS&time=2018",
                "Eurostat_gdp_head_2018" :
                "nama_10_pc?na_item=B1GQ&precision=1&unit=CLV10_EUR_HAB&time=2018",
                "Eurostat_health_euro_expenditure_per_capita_and_totals_2017" :
                "tps00207?precision=1&unit=EUR_HAB&unit=MIO_EUR&unit=PC_GDP&icha11_hc=TOT_HC&time=2017",
                "Eurostat_total_nights_spent_by_residents_non_residents_2018" :
                "tin00175?c_resid=FOR&c_resid=NAT&c_resid=TOTAL&precision=1&unit=NR&time=2018&nace_r2=I551-I553",
                "Eurostat_total_deaths_by_pneumonia_2016" :
                "tps00128?precision=1&sex=F&sex=M&sex=T&unit=RT&time=2016&age=TOTAL&icd10=J12-J18",
                "Eurostat_standardised_death_rate_due_to_chronic_diseases_by_sex" :
                "sdg_03_40?sex=F&sex=M&sex=T&precision=1&time=2016",
                "Eurostat_total_population_on_January1st_2018" :
                "proj_18np?precision=1&age=TOTAL",
                "Eurostat_no_of_practising_physicians_per_100k_inhabitants_2017" :
                "tps00044?precision=1&isco08=OC221&unit=P_HTHAB&wstatus=PRACT&time=2017",
                "Eurostat_share_of_people_with_good_or_very_good_perceived_health_by_sex_above_16_2019" :
                "sdg_03_20?precision=1&sex=F&sex=M&sex=T&unit=PC&quantile=TOTAL&time=2019&age=Y_GE16&levels=VG_G",
                "Eurostat_overcrowding_rate_by_sex_without_single-person_households_2019" :
                "tessi176?precision=1&sex=F&sex=M&sex=T&incgrp=TOTAL&unit=PC&time=2019&age=TOTAL",
                "Eurostat_population_by_age_group_2019" :
                "tps00010?indic_de=PC_Y0_14&indic_de=PC_Y15_24&indic_de=PC_Y25_49&indic_de=PC_Y50_64&indic_de=PC_Y65_79&indic_de=PC_Y80_MAX&precision=1&time=2019"
               }
df_list=[]

# %% [markdown]
# We now create a function, which:
# <br>
# <br>
# a) receives a string(URL-base) and a dictionary of strings(secondary URL components),
# <br>
# b) iterates through the dictionary,
# <br>
# c) concatenates the URL components,
# <br>
# d) reads the JSON files from the API
# <br>
# e) transforms it to a panda dataframe,
# <br>
# f) transforms the respective df into a CSV-file and saves it in the repository

# %%
def eurostat(base_str,url_dict):
    from pyjstat import pyjstat
    from collections import OrderedDict
    
    for key in url_dict:
        url = base_str + url_dict.get(key)
        dataset = pyjstat.Dataset.read(url)
        df = dataset.write('dataframe')
        # The next line is commented to avoid exporting files to CSV at each run of Jupyter notebook
        # To checkout the csv files, uncomment the line
        # df.to_csv(key +'.csv', index=False)
    return

# %%
# We will now call the function with the above created string variable and the URL-dictionary

# %%
eurostat(Eurostat_base,Eurostat_dict)

# %%
'''
Now we move the freshly created CSV files into a DATA subfolder in our repository. 
As a next step we import the CSV files into the previously created MySQL scheme "newcovid"
There we JOIN the new tables on column with the name of the European countries, 'geo',
and create one new table 'master':

USE newcovid;
CREATE TABLE master
SELECT eurostat_air_transport_passengers_2018.geo AS countries,
       eurostat_gdp_head_2018.value AS gdp_per_head_2018,
       eurostat_air_transport_passengers_2018.value AS air_transport_passengers_2018,
       eurostat_population_density_2018.value AS population_density_2018,
       eurostat_no_of_practising_physicians_per_100k_inhabitants_2017.value AS practPHYSICIANSp100kinh,
       eurostat_health_euro_expenditure_per_capita_and_totals_2017.value AS health_exp_in_€_pH,
       eurostat_total_deaths_by_pneumonia_2016.value AS deaths_pneumo_2016,
       eurostat_standardised_death_rate_due_to_chronic_diseases_by_sex.value AS death_rate_chronic_diseases,
       eurostat_total_nights_spent_by_residents_non_residents_2018.value AS total_nights_spent_hotels_2018,
       eurostat_total_population_on_january1st_2018.value AS total_population_2018
FROM eurostat_air_transport_passengers_2018
JOIN eurostat_gdp_head_2018
    ON eurostat_air_transport_passengers_2018.geo = eurostat_gdp_head_2018.geo
JOIN eurostat_health_euro_expenditure_per_capita_and_totals_2017
    ON eurostat_health_euro_expenditure_per_capita_and_totals_2017.geo = eurostat_air_transport_passengers_2018.geo
    AND eurostat_health_euro_expenditure_per_capita_and_totals_2017.unit = 'Euro per inhabitant'
JOIN eurostat_no_of_practising_physicians_per_100k_inhabitants_2017
    ON eurostat_no_of_practising_physicians_per_100k_inhabitants_2017.geo = eurostat_air_transport_passengers_2018.geo
JOIN eurostat_population_density_2018
    ON eurostat_population_density_2018.geo = eurostat_air_transport_passengers_2018.geo
JOIN eurostat_standardised_death_rate_due_to_chronic_diseases_by_sex
    ON eurostat_standardised_death_rate_due_to_chronic_diseases_by_sex.geo = eurostat_air_transport_passengers_2018.geo
    AND eurostat_standardised_death_rate_due_to_chronic_diseases_by_sex.sex = 'Total'
JOIN eurostat_total_deaths_by_pneumonia_2016
    ON eurostat_total_deaths_by_pneumonia_2016.geo = eurostat_air_transport_passengers_2018.geo
    AND eurostat_total_deaths_by_pneumonia_2016.sex ='Total'
JOIN eurostat_total_nights_spent_by_residents_non_residents_2018
    ON eurostat_total_nights_spent_by_residents_non_residents_2018.geo = eurostat_air_transport_passengers_2018.geo
    AND eurostat_total_nights_spent_by_residents_non_residents_2018.c_resid = 'total'
JOIN eurostat_total_population_on_january1st_2018
    ON eurostat_total_population_on_january1st_2018.geo = eurostat_air_transport_passengers_2018.geo
    AND eurostat_total_population_on_january1st_2018.sex = 'Total'
    AND eurostat_total_population_on_january1st_2018.time = '2018'
    AND eurostat_total_population_on_january1st_2018.projection = 'Baseline projections';

'''

## In the meantime Bita has collected the WHO Covid19 data (confirmed cases, deaths and recovered) for the latest day from the WHO using their API (as explained in 6.1)

''' 

While Bita already starts exploring plotting the WHO data with matlib.plot, 
she also exports the WHO data of April 7th, which we incorporate into our SQL scheme newcovid 
and join with the previously created  table as master_stats:

        CREATE TABLE master_stats
        Select *
        FROM master
        JOIN who7thapril
        ON who7thapril.Country = master.countries;

'''

## As a next step in MySQL, we sort master_stats in descending order for confirmed cases and deaths and scan for potential correlations with the numbers received from Eurostats.

'''
From here we now create tables with either and/or confirmed cases and deaths from WHO ands a small subset of columns from Eurostat like this one:

        CREATE TABLE deaths_conf_gdp_head_2018
        SELECT Country, Confirmed, Deaths, gdp_per_head_2018
        FROM master_stats;

For a better comparison of relative data we needed to also calculate the Covid19 death rate per 100.000 inhabitants 
by multiplying the number of deaths with 100.000 and dividing this by the total number of the population. 

        CREATE TABLE newcovid.deaths_phys_health_exp
        SELECT   deaths_phys_health_exp.Country, deaths_phys_health_exp.Deaths, 
                (master_stats.Deaths*100000)/master_stats.total_population_2018 AS Deaths_p100kinh, 
                deaths_phys_health_exp.practPHYSICIANSp100kinh, deaths_phys_health_exp.health_exp_in_€_pH
        FROM deaths_phys_health_exp
        JOIN master_stats
        ON master_stats.Country = deaths_phys_health_exp.Country;

These new tables we exported as CSV files into the respective DATA folder in our repository.
'''

# %%
# As a next step we import these CSV files into panda dataframes, i.e. 
# this one, which visualizes the number of Covid19 deaths and the public health expenditure in Euro per Head for each country
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_deaths_phys_health_exp2.csv')

# %%
# In preparation for the ensuing plotting we sort the dataframes in Descending order
df_Eurostat=df_Eurostat.sort_values(by = "practPHYSICIANSp100kinh", axis=0, ascending=False)

# %%
# Now thanks to all the plotting preparation work by Bita we are able to plot the tables

fig, ax = plt.subplots(figsize = (15,10))

ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
width = 0.4
df_Eurostat.Deaths_p100kinh.plot(kind='bar', color='y', ax=ax, width=width, position=1,label = "deaths from Covid19 per 100k inhabitants")
df_Eurostat.practPHYSICIANSp100kinh.plot(kind='bar', color='b', ax=ax2, width=width, position=2, label = "practicing physicians per 100k inhabitants")


ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('deaths from Covid19 per 100k inhabitants')
ax2.set_ylabel('practicing physicians per 100k inhabitants')
ax.set_title("Deaths from Covid19 vs. practicing physicians, each per 100k inhabitants")
ax.set_frame_on(False)

ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.70, 0.95), loc=2, borderaxespad=0.);


# we save a png file to the repository, which we then use for the project presentation
plt.savefig("Figures/DeathsvsPhysicians.png") # save as png

# %%
# From these graphs we cannot see an indication of correlation between deaths from Covid19 per 100,000 inhabitants and the
# number of practicing physicians per 100.000 inhabitants of the euiropean countries. They seem to be rather unrelated at this point.

# %%
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_confirmd_hotel_pass_percountry.csv')
df_Eurostat=df_Eurostat.sort_values(by = "Confirmed", axis=0, ascending=False)

# %%
fig, ax = plt.subplots(figsize = (15,10))
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax3 = ax.twinx() # Create another axes that shares the same x-axis as ax.
width = 0.25
df_Eurostat.Confirmed.plot(kind='bar', color='y', ax=ax, width=width, position=0, label = "Confirmed Cases")
df_Eurostat.total_nights_spent_hotels_2018.plot(kind='bar', color='b', ax=ax2, width=width, position=1, label = "total_nights_spent_hotels_2018")
par3 = df_Eurostat.air_transport_passengers_2018.plot(kind='bar', color='r', ax=ax3, width=width, position=2, label = "air_transport_passengers_2018")

# to create another vertical axis
par3.spines['right'].set_position(('outward', 50)) 

ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('Confirmed Cases')
ax2.set_ylabel('Confirmed SARS-CoV-2 Infections vs Annual Hotel-Nights Spent')
ax3.set_ylabel('Confirmed SARS-CoV-2 Infections vs Air Transport Passengers')
ax.set_title('Total confirmed cases of infection vs Annual Hotel-Nights Spent / Air Transport Passengers')
ax.set_frame_on(False)

ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.765, 0.95), loc=2, borderaxespad=0.);
ax3.legend(bbox_to_anchor=(0.765, 0.90), loc=2, borderaxespad=0.);



plt.savefig("Figures/Confirmed SARS-CoV-2 Infections vs Annual Hotel-Nights Spent-Air Transport Passengers.png") # save as png

# %%
# From these graphs we actually do see an indication of correlation between the total number of confirmed SARS-CoV-2 infections and the
# total number of hotel nights spent in a country in the european countries, especially for the countries with highest number of infections. 
# Also the number of air transport passengers in these countries are significantly higher than in the less affected countries.

# %%
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_confirm_popdens_percountry.csv')
df_Eurostat=df_Eurostat.sort_values(by = "Confirmed", axis=0, ascending=False)

# %%
fig, ax = plt.subplots(figsize = (15,10))

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.25
df_Eurostat.Confirmed.plot(kind='bar', color='b', ax=ax, width=width, position=0, label = 'Confirmed')
df_Eurostat.population_density_2018.plot(kind='bar', color='r', ax=ax2, width=width, position=1,label = 'Population density per sq-km')

ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('Confirmed Cases')
ax2.set_ylabel('population density per sq-km')
#ax.tick_params(labelrotation=90)
ax.set_title('Confirmed SARS-CoV-2 infections vs population density per sq-km')
ax.set_frame_on(False)


ax.legend(bbox_to_anchor=(0.75, 0.99), loc=2, borderaxespad=0.);
ax2.legend(bbox_to_anchor=(0.75, 0.94), loc=2, borderaxespad=0.);

plt.savefig("Figures/Confirmed SARS-CoV-2 infections vs population density per sq-km.png") # save as png

# %%
# From these graphs we cannot see an indication of correlation between confirmed SARS-CoV-2 infections and the
# population density per sq-km in the european countries. They seem to be rather unrelated at this point.

# %%
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_deaths_pneumod_chronicdrate.csv')
df_Eurostat=df_Eurostat.sort_values(by = "Deaths_p100kinh", axis=0, ascending=False)

# %%
fig, ax = plt.subplots(figsize = (15,10))
#fig = plt.figure() # Create matplotlib figure
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
width = 0.3
df_Eurostat.Deaths_p100kinh.plot(kind='bar', color='b', ax=ax, width=width, position=1 , label = 'Covid19 deaths per 100k inhabitants')
df_Eurostat.deaths_pneumo_2016.plot(kind='bar', color='r', ax=ax2, width=width, position=0 , label = 'deaths from pneumonia per 100k inhabitants in 2016')


ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('Covid19 deaths per 100k inhabitants')
ax2.set_ylabel('deaths from pneumonia per 100k inhabitants in 2016')
ax.set_title('Covid19 deaths vs deaths from pneumonia in 2016, each per 100k inhabitants ')
ax.set_frame_on(False)

ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.633, 0.95), loc=2, borderaxespad=0.);

plt.savefig("Figures/Covid19 deaths vs deaths from pneumonia in 2016 -each per 100k inhabitants.png") # save as png

# %%
# From this we cannot see an indication of correlation between Covid19 deaths and the
# death rate from pneumonia in the european countries. They seem to be rather unrelated at this point.

# %%
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_deaths_pneumod_chronicdrate.csv')
df_Eurostat=df_Eurostat.sort_values(by = "Deaths_p100kinh", axis=0, ascending=False)

# %%
fig, ax = plt.subplots(figsize = (15,10))
#fig = plt.figure() # Create matplotlib figure
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
width = 0.25
df_Eurostat.Deaths_p100kinh.plot(kind='bar', color='b', ax=ax, width=width, position=0 , label = 'Covid19 deaths per 100k inhabitants')
#df_Eurostat.deaths_pneumo_2016.plot(kind='bar', color='y', ax=ax2, width=width, position=1)
df_Eurostat.death_rate_chronic_diseases.plot(kind='bar', color='y', ax=ax2, width=width, position=1, label = 'death rate from chronic diseases 2016')

ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('Covid19 deaths per 100k inhabitants')
ax2.set_ylabel('death rate from chronic diseases 2016 per 100k inhabitants')
#ax.tick_params(labelrotation=90)
ax.set_title('Covid19 deaths per 100k inhabitants vs death rate from chronic diseases per 100k inhabitants 2016')
ax.set_frame_on(False)
ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.72, 0.95), loc=2, borderaxespad=0.);


plt.savefig("Figures/Covid19 deaths per 100k inhabitants vs death rate from chronic diseases 2016.png") # save as png

# %%
# From these graphs we cannot see an indication of correlation between Covid19 deaths per 100.000 inhabitants and the
# death rate from chronic diseases in the european countries. They seem to be rather unrelated at this point.

# %%
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_deaths_conf_gdp_head_2018.csv')
df_Eurostat=df_Eurostat.sort_values(by = "Deaths_p100kinh", axis=0, ascending=False)

# %%
fig, ax = plt.subplots(figsize = (15,10))
#fig = plt.figure() # Create matplotlib figure
ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax3 = ax.twinx() # Create another axes that shares the same x-axis as ax.
width = 0.35
df_Eurostat.Deaths_p100kinh.plot(kind='bar', color='r', ax=ax, width=width, position=1 , label = 'Covid19 deaths p100k')
df_Eurostat.gdp_per_head_2018.plot(kind='bar', color='y', ax=ax2, width=width, position=0, label = 'GDP in Euro per head')

ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('Covid19 deaths p100k')
ax2.set_ylabel('GDP in Euro per head')
ax.set_title('Covid19 deaths p100k vs GDP in Euro per head')
ax.set_frame_on(False)

ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.82, 0.95), loc=2, borderaxespad=0.);

plt.savefig("Figures/Covid19 deaths p100k vs GDP in Euro per head.png") # save as png

# %%
# From these graphs we can see an indication of correlation between Covid19 deaths per 100.000 inhabitants and 
# the lower-midrange GDP per Head numbers of those european countries with high death rates.
# None of the Top 5 GDP per Head countries are amongst the countries with the highest death rates from Covid19.
# Further investigation would be advisable.

# %%
df_Eurostat = pd.read_csv(r'Data/CSV-Files/From_MySQL_newcovid/newcovid_deaths_conf_gdp_head_2018.csv')
df_Eurostat=df_Eurostat.sort_values(by = "gdp_per_head_2018", axis=0, ascending=False)

# %%
fig, ax = plt.subplots(figsize = (15,10))

ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
width = 0.35
df_Eurostat.Confirmed_p100kinh.plot(kind='bar', color='b', ax=ax, width=width, position=0, label = 'Confirmed cases per 100k inhabitants')
df_Eurostat.gdp_per_head_2018.plot(kind='bar', color='y', ax=ax2, width=width, position=1, label = 'GDP in Euro per head')


ax.set_xticklabels(df_Eurostat.Country, rotation=90)
ax2.set_xticklabels(df_Eurostat.Country, rotation=90)
ax.set_ylabel('Confirmed cases per 100.000 inhabitants')
ax2.set_ylabel('GDP in Euro per head')
#ax.tick_params(labelrotation=90)
ax.set_title('Confirmed cases per 100.000 inhabitants vs GDP in Euro per head')

ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.82, 0.95), loc=2, borderaxespad=0.);

plt.savefig("Figures/Confirmed cases p100k vs GDP in Euro per head.png") # save as png

# %%
# These graphs, with the exception of Luxembourg, indicate that higher GDP per Head correlate with lower Covid19 confirmed cases per 100.000 inhabitants and 
# that some of the countries with highest Covid19 confirmed cases per 100.000 inhabitants show lower GDP per head numbers. 
# The results are not unambiguous though.
# Further investigation would be advisable.

# %% [markdown]
# ## 7. Further Data Analysis and data processing possibilities

# %%
# For alternative and more automated ways of obtaining API data, building data frames and plotting them directly in Jupyter:
# /WiP/Bita/ReadPlotData.ipynb (line 365 ff)

# %%
# For deeper analysis of correlations between Covid19 figures and socio economic data available a much more indepth mathematical approach is necessary.
# Further study is needed and methods like regression analysis need to be applied to the data we want to evaluate.
