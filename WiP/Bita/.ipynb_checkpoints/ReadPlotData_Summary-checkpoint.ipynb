# %%
import pandas as pd
import datetime
import re
import requests
import bs4
import matplotlib.pyplot as plt
#import matplotlib
from IPython.display import display, HTML
import numpy as np

# %%
# Plot Covid data from WHO
# Covid data was downloaded with:
# curl --location --request GET 'https://api.covid19api.com/all' > covidwho.json

# %%
df_who = pd.read_json (r'data-who/covidwho.json')

# %%
df_who.head()
# Out:
#        Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 0  Afghanistan          AF  33.94  67.71          0       0          0
# 1  Afghanistan          AF  33.94  67.71          0       0          0
# 2  Afghanistan          AF  33.94  67.71          0       0          0
# 3  Afghanistan          AF  33.94  67.71          0       0          0
# 4  Afghanistan          AF  33.94  67.71          0       0          0
#
#    Active                      Date                            LocationID  \
# 0       0 2020-01-22 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 1       0 2020-01-23 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 2       0 2020-01-24 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 3       0 2020-01-25 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 4       0 2020-01-26 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
#
#   Province City CityCode
# 0      NaN  NaN      NaN
# 1      NaN  NaN      NaN
# 2      NaN  NaN      NaN
# 3      NaN  NaN      NaN
# 4      NaN  NaN      NaN

# %%
df_who_Germany = df_who[df_who['Country'] =="Germany"]
df_who_Germany
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 9629  Germany          DE  51.17  10.45          0       0          0       0
# 9630  Germany          DE  51.17  10.45          0       0          0       0
# 9631  Germany          DE  51.17  10.45          0       0          0       0
# 9632  Germany          DE  51.17  10.45          0       0          0       0
# 9633  Germany          DE  51.17  10.45          0       0          0       0
# ...       ...         ...    ...    ...        ...     ...        ...     ...
# 9701  Germany          DE  51.17  10.45      91159    1275      24575       0
# 9702  Germany          DE  51.17  10.45      96092    1444      26400       0
# 9703  Germany          DE  51.17  10.45     100123    1584      28700       0
# 9704  Germany          DE  51.17  10.45     103374    1810      28700       0
# 9705  Germany          DE  51.17  10.45     107663    2016      36081       0
#
#                           Date                            LocationID Province  \
# 9629 2020-01-22 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9630 2020-01-23 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9631 2020-01-24 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9632 2020-01-25 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9633 2020-01-26 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# ...                        ...                                   ...      ...
# 9701 2020-04-03 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9702 2020-04-04 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9703 2020-04-05 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9704 2020-04-06 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
# 9705 2020-04-07 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN
#
#      City CityCode
# 9629  NaN      NaN
# 9630  NaN      NaN
# 9631  NaN      NaN
# 9632  NaN      NaN
# 9633  NaN      NaN
# ...   ...      ...
# 9701  NaN      NaN
# 9702  NaN      NaN
# 9703  NaN      NaN
# 9704  NaN      NaN
# 9705  NaN      NaN
#
# [77 rows x 13 columns]

# %%
df_who_Italy = df_who[df_who['Country'] =="Italy"]
df_who_Italy
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 11092   Italy          IT  41.87  12.57          0       0          0       0
# 11093   Italy          IT  41.87  12.57          0       0          0       0
# 11094   Italy          IT  41.87  12.57          0       0          0       0
# 11095   Italy          IT  41.87  12.57          0       0          0       0
# 11096   Italy          IT  41.87  12.57          0       0          0       0
# ...       ...         ...    ...    ...        ...     ...        ...     ...
# 11164   Italy          IT  41.87  12.57     119827   14681      19758       0
# 11165   Italy          IT  41.87  12.57     124632   15362      20996       0
# 11166   Italy          IT  41.87  12.57     128948   15887      21815       0
# 11167   Italy          IT  41.87  12.57     132547   16523      22837       0
# 11168   Italy          IT  41.87  12.57     135586   17127      24392       0
#
#                            Date                            LocationID  \
# 11092 2020-01-22 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11093 2020-01-23 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11094 2020-01-24 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11095 2020-01-25 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11096 2020-01-26 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# ...                         ...                                   ...
# 11164 2020-04-03 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11165 2020-04-04 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11166 2020-04-05 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11167 2020-04-06 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11168 2020-04-07 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
#
#       Province City CityCode
# 11092      NaN  NaN      NaN
# 11093      NaN  NaN      NaN
# 11094      NaN  NaN      NaN
# 11095      NaN  NaN      NaN
# 11096      NaN  NaN      NaN
# ...        ...  ...      ...
# 11164      NaN  NaN      NaN
# 11165      NaN  NaN      NaN
# 11166      NaN  NaN      NaN
# 11167      NaN  NaN      NaN
# 11168      NaN  NaN      NaN
#
# [77 rows x 13 columns]

# %%
df_who_Spain = df_who[df_who['Country'] =="Spain"]
df_who_Spain
# Out:
#       Country CountryCode    Lat   Lon  Confirmed  Deaths  Recovered  Active  \
# 16870   Spain          ES  40.46 -3.75          0       0          0       0
# 16871   Spain          ES  40.46 -3.75          0       0          0       0
# 16872   Spain          ES  40.46 -3.75          0       0          0       0
# 16873   Spain          ES  40.46 -3.75          0       0          0       0
# 16874   Spain          ES  40.46 -3.75          0       0          0       0
# ...       ...         ...    ...   ...        ...     ...        ...     ...
# 16942   Spain          ES  40.46 -3.75     119199   11198      30513       0
# 16943   Spain          ES  40.46 -3.75     126168   11947      34219       0
# 16944   Spain          ES  40.46 -3.75     131646   12641      38080       0
# 16945   Spain          ES  40.46 -3.75     136675   13341      40437       0
# 16946   Spain          ES  40.46 -3.75     141942   14045      43208       0
#
#                            Date                            LocationID  \
# 16870 2020-01-22 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16871 2020-01-23 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16872 2020-01-24 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16873 2020-01-25 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16874 2020-01-26 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# ...                         ...                                   ...
# 16942 2020-04-03 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16943 2020-04-04 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16944 2020-04-05 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16945 2020-04-06 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 16946 2020-04-07 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
#
#       Province City CityCode
# 16870      NaN  NaN      NaN
# 16871      NaN  NaN      NaN
# 16872      NaN  NaN      NaN
# 16873      NaN  NaN      NaN
# 16874      NaN  NaN      NaN
# ...        ...  ...      ...
# 16942      NaN  NaN      NaN
# 16943      NaN  NaN      NaN
# 16944      NaN  NaN      NaN
# 16945      NaN  NaN      NaN
# 16946      NaN  NaN      NaN
#
# [77 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.plot(df_who_Germany['Date'], df_who_Germany['Confirmed'], zorder=1 , color="g",label = "Germany")
plt.plot(df_who_Italy['Date'], df_who_Italy['Confirmed'], zorder=2 , color="b" , label = "Italy")
plt.plot(df_who_Spain['Date'], df_who_Spain['Confirmed'], zorder=3 , color="r", label = "Spain")
ax.set_title("Confirmed")

plt.legend(loc="upper left");
# Out:
# /home/bita/anaconda3/envs/backpack1/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.plot(df_who_Germany['Date'], df_who_Germany['Deaths'], zorder=1 , color="g",label = "Germany")
plt.plot(df_who_Italy['Date'], df_who_Italy['Deaths'], zorder=2 , color="b", label = "Italy")
plt.plot(df_who_Spain['Date'], df_who_Spain['Deaths'], zorder=3 , color="r", label = "Spain")
ax.set_title("Deaths")

plt.legend(loc="upper left");

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.plot(df_who_Germany['Date'], df_who_Germany['Recovered'], zorder=1 , color="g",label = "Germany")
plt.plot(df_who_Italy['Date'], df_who_Italy['Recovered'], zorder=2 , color="b", label = "Italy")
plt.plot(df_who_Spain['Date'], df_who_Spain['Recovered'], zorder=3 , color="r", label = "Spain")
ax.set_title("Recovered")

plt.legend(loc="upper left");

# %%
# Selected Countries for the Analysis

# %%
#countries_sel = ["Germany","Italy","Spain","Malta"]
#from HDI Index
countries_sel = ["Norway", "Ireland", "Germany","Sweden","Netherlands","Denmark","Finland","United Kingdo",
                 "Belgium","Austria", "Luxembourg","Sloenia","Spain","France","Czechia","Malta","Estonia","Italy","Cyprus","Greece",
    "Lithuania","Poland","Slovakia","Latvia","Portugal","Hungary","Croatia","Bulgaria","Romania"]

# %%
# Plot HDI Score

# %%
hdi_score = pd.read_csv('data_HDI_EU.csv')

# %%
#hdi_score.set_index("geo")
fig, ax = plt.subplots(figsize = (13,8))

ax.bar(hdi_score["geo"],
       hdi_score["HDI_score_2017"],
       color = 'y');
ax.tick_params(labelrotation=90)
ax.set_title("HDI score 2017")
ax.set_ylabel("HDI")
ax.set_frame_on(False)

plt.axhline(y=1, xmin=0.0, xmax=1, label = "high: 0.8-1", linewidth=1, color = 'g', );
plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'b', );
plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );

plt.legend(loc="lower center");

# %%
# Extract data from the last Date (7th of April)

df_who_lastday = df_who[df_who['Date'] =="2020-04-07 00:00:00+00:00"]

# %%
df_who_lastday
# Out:
#                                 Country CountryCode    Lat     Lon  Confirmed  \
# 76                          Afghanistan          AF  33.94   67.71        423
# 153                             Albania          AL  41.15   20.17        383
# 230                             Algeria          DZ  28.03    1.66       1468
# 307                             Andorra          AD  42.55    1.60        545
# 384                              Angola          AO -11.20   17.87         17
# ...                                 ...         ...    ...     ...        ...
# 263241  Venezuela (Bolivarian Republic)          VE   6.42  -66.59        165
# 263318                         Viet Nam          VN  14.06  108.28        249
# 263322                   Western Sahara          EH  24.22  -12.89          4
# 263399                           Zambia          ZM -13.13   27.85         39
# 263476                         Zimbabwe          ZW -19.02   29.15         11
#
#         Deaths  Recovered  Active                      Date  \
# 76          14         18       0 2020-04-07 00:00:00+00:00
# 153         22        131       0 2020-04-07 00:00:00+00:00
# 230        193        113       0 2020-04-07 00:00:00+00:00
# 307         22         39       0 2020-04-07 00:00:00+00:00
# 384          2          2       0 2020-04-07 00:00:00+00:00
# ...        ...        ...     ...                       ...
# 263241       7         65       0 2020-04-07 00:00:00+00:00
# 263318       0        123       0 2020-04-07 00:00:00+00:00
# 263322       0          0       0 2020-04-07 00:00:00+00:00
# 263399       1          7       0 2020-04-07 00:00:00+00:00
# 263476       2          0       0 2020-04-07 00:00:00+00:00
#
#                                   LocationID Province City CityCode
# 76      828ca7f3-144f-4732-b659-a60f97755626      NaN  NaN      NaN
# 153     07ef547a-c2a5-4279-8f24-0295e9c7fe7a      NaN  NaN      NaN
# 230     e6bec38b-4eae-4ce4-bbaf-69f532c1bd5f      NaN  NaN      NaN
# 307     9f52c049-2008-45d8-8f86-7c009e015d17      NaN  NaN      NaN
# 384     8bba7786-aabb-423a-97a1-7140fa6dfe19      NaN  NaN      NaN
# ...                                      ...      ...  ...      ...
# 263241  a10e89ba-91bb-42ca-b089-caa55cf10114      NaN  NaN      NaN
# 263318  5d4d26ec-5215-4595-88c3-4f28d4580ebb      NaN  NaN      NaN
# 263322  71656d15-e630-4136-8205-87a14968d634      NaN  NaN      NaN
# 263399  2b3f6ef0-a3bf-41a8-8a91-8b79d8c36105      NaN  NaN      NaN
# 263476  ea6b4f98-988c-4ff1-b6e9-3d75c654ea0f      NaN  NaN      NaN
#
# [3511 rows x 13 columns]

# %%
#select countries from the list of countries (Countries that we like to study)

df_who_lastday_sel_none_unique = df_who_lastday[df_who_lastday.Country.str.contains('|'.join(countries_sel))]

# %%
df_who_lastday_sel_none_unique
# Out:
#               Country CountryCode    Lat     Lon  Confirmed  Deaths  \
# 1308          Austria          AT  47.52   14.55      12639     243
# 1847          Belgium          BE  50.50    4.47      22194    2035
# 2540         Bulgaria          BG  42.73   25.49        577      23
# 7237          Croatia          HR  45.10   15.20       1282      18
# 7391           Cyprus          CY  35.13   33.43        494       9
# 7697          Denmark          DK  56.26    9.50       5071     203
# 7698          Denmark          DK  61.89   -6.91        184       0
# 7699          Denmark          DK  71.71  -42.60         11       0
# 8392          Estonia          EE  58.60   25.01       1149      21
# 8623          Finland          FI  61.92   25.75       2308      34
# 9387           France          FR  46.89  -56.32          1       0
# 9388           France          FR  16.25  -61.58        139       7
# 9389           France          FR -12.83   45.17        171       2
# 9390           France          FR -17.68  149.41         47       0
# 9391           France          FR   3.93  -53.13         72       0
# 9392           France          FR -21.14   55.25        358       0
# 9393           France          FR -20.90  165.62         18       0
# 9394           France          FR  18.07  -63.05         32       2
# 9395           France          FR  17.90  -62.83          6       0
# 9396           France          FR  46.23    2.21     109069   10328
# 9397           France          FR  14.64  -61.02        152       4
# 9705          Germany          DE  51.17   10.45     107663    2016
# 9859           Greece          GR  39.07   21.82       1832      81
# 10552         Hungary          HU  47.16   19.50        817      47
# 11014         Ireland          IE  53.41   -8.24       5709     210
# 11168           Italy          IT  41.87   12.57     135586   17127
# 11938          Latvia          LV  56.88   24.60        548       2
# 12323       Lithuania          LT  55.17   23.88        880      15
# 12400      Luxembourg          LU  49.82    6.13       2970      44
# 12939           Malta          MT  35.94   14.38        293       0
# 14244     Netherlands          NL  12.17  -68.99         13       1
# 14245     Netherlands          NL  12.18  -68.24          2       0
# 14246     Netherlands          NL  18.04  -63.05         40       6
# 14247     Netherlands          NL  12.52  -70.04         74       0
# 14248     Netherlands          NL  52.13    5.29      19580    2101
# 14633          Norway          NO  60.47    8.47       6086      89
# 15326          Poland          PL  51.92   19.15       4848     129
# 15403        Portugal          PT  39.40   -8.22      12442     345
# 15634         Romania          RO  45.94   24.97       4417     197
# 16638        Slovakia          SK  48.67   19.70        581       2
# 16946           Spain          ES  40.46   -3.75     141942   14045
# 17331          Sweden          SE  60.13   18.64       7693     591
# 19101       Falkland Islands (Malvinas)  Falkland Islands (Islas Malvinas)
# 19102                         Gibraltar                          Gibraltar
# 19103            British Virgin Islands             British Virgin Islands
# 19104                       Isle of Man                        Isle of Man
# 19105          Turks and Caicos Islands           Turks and Caicos Islands
# 19106                          Anguilla                           Anguilla
# 19107                               NaN                                NaN

# %%
# The list above had multiple values for e.g France (e.g. Reunio). We discard those Provinces...
df_who_lastday_sel = df_who_lastday_sel_none_unique[df_who_lastday_sel_none_unique['Province'].isna()]
df_who_lastday_sel
# Out:
#               Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 1308          Austria          AT  47.52  14.55      12639     243       4046
# 1847          Belgium          BE  50.50   4.47      22194    2035       4157
# 2540         Bulgaria          BG  42.73  25.49        577      23         42
# 7237          Croatia          HR  45.10  15.20       1282      18        167
# 7391           Cyprus          CY  35.13  33.43        494       9         47
# 7697          Denmark          DK  56.26   9.50       5071     203       1491
# 8392          Estonia          EE  58.60  25.01       1149      21         69
# 8623          Finland          FI  61.92  25.75       2308      34        300
# 9396           France          FR  46.23   2.21     109069   10328      19337
# 9705          Germany          DE  51.17  10.45     107663    2016      36081
# 9859           Greece          GR  39.07  21.82       1832      81        269
# 10552         Hungary          HU  47.16  19.50        817      47         71
# 11014         Ireland          IE  53.41  -8.24       5709     210         25
# 11168           Italy          IT  41.87  12.57     135586   17127      24392
# 11938          Latvia          LV  56.88  24.60        548       2         16
# 12323       Lithuania          LT  55.17  23.88        880      15          8
# 12400      Luxembourg          LU  49.82   6.13       2970      44        500
# 12939           Malta          MT  35.94  14.38        293       0          5
# 14248     Netherlands          NL  52.13   5.29      19580    2101        250
# 14633          Norway          NO  60.47   8.47       6086      89         32
# 15326          Poland          PL  51.92  19.15       4848     129        191
# 15403        Portugal          PT  39.40  -8.22      12442     345        184
# 15634         Romania          RO  45.94  24.97       4417     197        460
# 16638        Slovakia          SK  48.67  19.70        581       2         13
# 16946           Spain          ES  40.46  -3.75     141942   14045      43208
# 17331          Sweden          SE  60.13  18.64       7693     591        205
# 19107  United Kingdom          GB  55.38  -3.44      55242    6159        135
#
#        Active                      Date                            LocationID  \
# 1308        0 2020-04-07 00:00:00+00:00  39ca28f2-2ade-49f4-9516-e9b8cd8f48e6
# 1847        0 2020-04-07 00:00:00+00:00  1c49b6bb-1b83-4fe3-b536-da1731fe6953
# 2540        0 2020-04-07 00:00:00+00:00  de959b36-8cda-4645-9675-acc067f8fa56
# 7237        0 2020-04-07 00:00:00+00:00  b43d07be-a945-4525-91a2-b1fb47d46c2f
# 7391        0 2020-04-07 00:00:00+00:00  024ac3a0-b462-4db7-a25f-3774f3c34aaa
# 7697        0 2020-04-07 00:00:00+00:00  761966af-c2cf-4bd9-a375-2c4198cff021
# 8392        0 2020-04-07 00:00:00+00:00  d255c144-46dc-4320-8265-0060fabcdee0
# 8623        0 2020-04-07 00:00:00+00:00  bc1adb31-d848-4cfd-a898-194fe9376367
# 9396        0 2020-04-07 00:00:00+00:00  c6189b06-e1f8-47c5-b975-0110c1b6e78f
# 9705        0 2020-04-07 00:00:00+00:00  f770bd88-1a35-4430-bdbc-be3c62afc16b
# 9859        0 2020-04-07 00:00:00+00:00  70392d48-d54a-4f21-9336-1653fcca137e
# 10552       0 2020-04-07 00:00:00+00:00  86b5483f-a35c-4c17-a34d-c88d5a04b048
# 11014       0 2020-04-07 00:00:00+00:00  9d330a1e-5c20-4205-b20a-88ef0977e936
# 11168       0 2020-04-07 00:00:00+00:00  5bb4a80b-f42d-4622-b55e-bfcc9d24c574
# 11938       0 2020-04-07 00:00:00+00:00  759dd379-0fd6-4826-aa12-4f39b4f2ebdd
# 12323       0 2020-04-07 00:00:00+00:00  670e3a25-597e-4fdb-9d6e-239fed120525
# 12400       0 2020-04-07 00:00:00+00:00  e6c04ef0-76af-4322-a1b1-db148ff287b6
# 12939       0 2020-04-07 00:00:00+00:00  03e68e52-4ad5-4b28-873a-13bc654baf3a
# 14248       0 2020-04-07 00:00:00+00:00  4fd2b0ff-7680-4fb5-8d0c-ffd01b49d849
# 14633       0 2020-04-07 00:00:00+00:00  2abc0f85-1950-4d1e-b364-1be2242c1e19
# 15326       0 2020-04-07 00:00:00+00:00  4224d04c-7225-4988-9341-cfc60ac1ec52
# 15403       0 2020-04-07 00:00:00+00:00  993f0da3-ad2e-4699-84fa-b912b3829ee4
# 15634       0 2020-04-07 00:00:00+00:00  487e9392-3fe2-4343-9ca8-37f823fca6b5
# 16638       0 2020-04-07 00:00:00+00:00  62562dc8-23e5-4da5-bdbf-906f3a6d05c5
# 16946       0 2020-04-07 00:00:00+00:00  b4241151-a623-4529-ac08-9ff297410543
# 17331       0 2020-04-07 00:00:00+00:00  d6e8b61f-589a-4d3b-8d5d-5b01b31d44b6
# 19107       0 2020-04-07 00:00:00+00:00  32aadebc-ff17-40f7-9e6a-1277168074f9
#
#       Province City CityCode
# 1308       NaN  NaN      NaN
# 1847       NaN  NaN      NaN
# 2540       NaN  NaN      NaN
# 7237       NaN  NaN      NaN
# 7391       NaN  NaN      NaN
# 7697       NaN  NaN      NaN
# 8392       NaN  NaN      NaN
# 8623       NaN  NaN      NaN
# 9396       NaN  NaN      NaN
# 9705       NaN  NaN      NaN
# 9859       NaN  NaN      NaN
# 10552      NaN  NaN      NaN
# 11014      NaN  NaN      NaN
# 11168      NaN  NaN      NaN
# 11938      NaN  NaN      NaN
# 12323      NaN  NaN      NaN
# 12400      NaN  NaN      NaN
# 12939      NaN  NaN      NaN
# 14248      NaN  NaN      NaN
# 14633      NaN  NaN      NaN
# 15326      NaN  NaN      NaN
# 15403      NaN  NaN      NaN
# 15634      NaN  NaN      NaN
# 16638      NaN  NaN      NaN
# 16946      NaN  NaN      NaN
# 17331      NaN  NaN      NaN
# 19107      NaN  NaN      NaN

# %%
# Extract Data for further analysis in MySQL (joining with EUROSTAT data)
#df_who_lastday_sel.to_csv("WHO7thApril.csv", index=False)

# %%
# rename hdi table's name from geo to Country
hdi_score.rename(columns={'geo':'Country'}, inplace=True)

# %%
# Merge hdi index and death values based on Countries
hdi_combined = pd.merge(hdi_score, df_who_lastday_sel, on="Country")
#
#                               LocationID Province City CityCode
# 0   2abc0f85-1950-4d1e-b364-1be2242c1e19      NaN  NaN      NaN
# 1   9d330a1e-5c20-4205-b20a-88ef0977e936      NaN  NaN      NaN
# 2   f770bd88-1a35-4430-bdbc-be3c62afc16b      NaN  NaN      NaN
# 3   d6e8b61f-589a-4d3b-8d5d-5b01b31d44b6      NaN  NaN      NaN
# 4   4fd2b0ff-7680-4fb5-8d0c-ffd01b49d849      NaN  NaN      NaN
# 5   761966af-c2cf-4bd9-a375-2c4198cff021      NaN  NaN      NaN
# 6   bc1adb31-d848-4cfd-a898-194fe9376367      NaN  NaN      NaN
# 7   32aadebc-ff17-40f7-9e6a-1277168074f9      NaN  NaN      NaN
# 8   1c49b6bb-1b83-4fe3-b536-da1731fe6953      NaN  NaN      NaN
# 9   39ca28f2-2ade-49f4-9516-e9b8cd8f48e6      NaN  NaN      NaN
# 10  e6c04ef0-76af-4322-a1b1-db148ff287b6      NaN  NaN      NaN
# 11  b4241151-a623-4529-ac08-9ff297410543      NaN  NaN      NaN
# 12  c6189b06-e1f8-47c5-b975-0110c1b6e78f      NaN  NaN      NaN
# 13  03e68e52-4ad5-4b28-873a-13bc654baf3a      NaN  NaN      NaN
# 14  d255c144-46dc-4320-8265-0060fabcdee0      NaN  NaN      NaN
# 15  5bb4a80b-f42d-4622-b55e-bfcc9d24c574      NaN  NaN      NaN
# 16  024ac3a0-b462-4db7-a25f-3774f3c34aaa      NaN  NaN      NaN
# 17  70392d48-d54a-4f21-9336-1653fcca137e      NaN  NaN      NaN
# 18  670e3a25-597e-4fdb-9d6e-239fed120525      NaN  NaN      NaN
# 19  4224d04c-7225-4988-9341-cfc60ac1ec52      NaN  NaN      NaN
# 20  62562dc8-23e5-4da5-bdbf-906f3a6d05c5      NaN  NaN      NaN
# 21  759dd379-0fd6-4826-aa12-4f39b4f2ebdd      NaN  NaN      NaN
# 22  993f0da3-ad2e-4699-84fa-b912b3829ee4      NaN  NaN      NaN
# 23  86b5483f-a35c-4c17-a34d-c88d5a04b048      NaN  NaN      NaN
# 24  b43d07be-a945-4525-91a2-b1fb47d46c2f      NaN  NaN      NaN
# 25  de959b36-8cda-4645-9675-acc067f8fa56      NaN  NaN      NaN
# 26  487e9392-3fe2-4343-9ca8-37f823fca6b5      NaN  NaN      NaN

# %%
## The best plot sofar for the HDI


fig, ax = plt.subplots(figsize = (15,10))


ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
ax3 = ax.twinx() # Create another axes that shares the same x-axis as ax.


plt.gca().axes.get_yaxis().set_visible(False)


width = 0.4


p1 = hdi_combined.HDI_score_2017.plot(kind='bar', color='y', ax=ax, width=width, position=1,label = 'HDI')
p2 = hdi_combined.Deaths.plot(kind='bar', color='b', ax=ax2, width=width, position=0, label = 'Deaths')


p3 = plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'g', );
p4 = plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );


ax.set_xticklabels(hdi_combined.Country, rotation=90)
ax.set_ylabel('HDI score 2018')
ax2.set_ylabel('Deaths')
#ax.tick_params(labelrotation=90)
ax.set_title("HDI score (2018) vs. no. of deaths")
ax.set_frame_on(False)


ax.legend(loc="upper right");
ax2.legend(bbox_to_anchor=(0.91, 0.95), loc=2, borderaxespad=0.);
ax3.legend(bbox_to_anchor=(0.86, 0.91), loc=2, borderaxespad=0.);


plt.savefig("HDI-Deaths2.png") # save as png

# %%
# Import Eurostat data that is combined with each other and COVID Data from WHO in MySQL
df_Eurostat = pd.read_csv("master_stats.csv")
df_Eurostat
# Out:
#     Unnamed: 0  gdp_per_head_2018  air_transport_passengers_2018  \
# 0            0            37810.0                       31138417
# 1            1            35600.0                       34506294
# 2            2             6550.0                       12137714
# 3            3            23770.0                       10927101
# 4            4            35860.0                      222422361
# 5            5            48260.0                       34701139
# 6            6            15090.0                        2995528
# 7            7            24880.0                      220611429
# 8            8            36850.0                       22173530
# 9            9            32830.0                      161991179
# 10          10            11990.0                        9731294
# 11          11            12560.0                       15176493
# 12          12            57960.0                       36345005
# 13          13            26740.0                      153352444
# 14          14            13310.0                        6254178
# 15          15            83470.0                        3988804
# 16          16            12140.0                        7037081
# 17          17            21670.0                        6805817
# 18          18            41540.0                       79644055
# 19          19            69530.0                       40030105
# 20          20                NaN                       43767548
# 21          21             8740.0                       19809642
# 22          22            43810.0                       38945096
# 23          23            32700.0                      272190155
#
#     population_density_2018  practPHYSICIANSp100kinh  health_exp_in_€_pH  \
# 0                     107.1                   518.28             4371.34
# 1                     375.3                   308.29             3991.58
# 2                      63.9                   424.49              591.11
# 3                      94.4                   386.84             1527.71
# 4                     234.7                   424.88             4459.36
# 5                     138.0                      NaN             5134.04
# 6                      30.4                   346.82             1152.52
# 7                      93.1                   387.68             2221.11
# 8                      18.1                      NaN             3742.34
# 9                     105.6                   315.80             3883.02
# 10                     73.2                   336.21              805.33
# 11                    107.1                   332.48              871.95
# 12                     70.9                   306.57             4395.41
# 13                    202.9                   398.95             2522.52
# 14                     44.7                   455.63              963.25
# 15                    235.1                   298.49             5082.84
# 16                     30.4                   320.50              828.80
# 17                   1548.3                   396.37             2249.54
# 18                    504.0                   358.22             4345.73
# 19                     17.2                   465.85             7013.51
# 20                    123.6                   237.75                 NaN
# 21                     83.1                   292.68              493.78
# 22                     25.0                      NaN             5206.34
# 23                    273.8                   281.10             3408.88
#
#     deaths_pneumo_2016  death_rate_chronic_diseases  \
# 0                11.33                        103.7
# 1                35.27                         99.3
# 2                18.98                        193.9
# 3                12.49                         82.4
# 4                20.94                        112.0
# 5                35.21                        108.9
# 6                19.32                        155.8
# 7                17.97                         94.7
# 8                 2.88                        101.0
# 9                17.89                        101.8
# 10               16.53                        169.8
# 11               11.75                        243.7
# 12               39.28                         96.8
# 13               14.35                         84.6
# 14               19.91                        224.4
# 15               20.85                         94.7
# 16               18.79                        216.6
# 17               27.85                        101.6
# 18               22.22                         97.3
# 19               34.75                         79.8
# 20               43.31                        153.7
# 21               36.49                        229.8
# 22               18.18                         78.7
# 23               49.47                        113.3
#
#     total_nights_spent_hotels_2018  total_population_2018         Country  \
# 0                      125229170.0                8822267         Austria
# 1                       41320284.0               11398589         Belgium
# 2                       26845013.0                7050034        Bulgaria
# 3                       17164182.0                 864236          Cyprus
# 4                      419556284.0               82792351         Germany
# 5                       33280395.0                5781190         Denmark
# 6                        6630315.0                1319133         Estonia
# 7                      466940717.0               46658447           Spain
# 8                       22235084.0                5513130         Finland
# 9                      442760050.0               66926166          France
# 10                      89567653.0                4105493         Croatia
# 11                      32830120.0                9778371         Hungary
# 12                             NaN                4830392         Ireland
# 13                     428844937.0               60483973           Italy
# 14                       8091647.0                2808901       Lithuania
# 15                       2920245.0                 602005      Luxembourg
# 16                       5368739.0                1934379          Latvia
# 17                      10114196.0                 475701           Malta
# 18                     116081577.0               17181084     Netherlands
# 19                             NaN                5295619          Norway
# 20                      88860463.0               37976687          Poland
# 21                      28461153.0               19530631         Romania
# 22                      60856874.0               10120242          Sweden
# 23                             NaN               66273576  United Kingdom
#
#     Confirmed  Deaths  Recovered
# 0       12639     243       4046
# 1       22194    2035       4157
# 2         577      23         42
# 3         494       9         47
# 4      107663    2016      36081
# 5        5071     203       1491
# 6        1149      21         69
# 7      141942   14045      43208
# 8        2308      34        300
# 9      109069   10328      19337
# 10       1282      18        167
# 11        817      47         71
# 12       5709     210         25
# 13     135586   17127      24392
# 14        880      15          8
# 15       2970      44        500
# 16        548       2         16
# 17        293       0          5
# 18      19580    2101        250
# 19       6086      89         32
# 20       4848     129        191
# 21       4417     197        460
# 22       7693     591        205
# 23      55242    6159        135

# %%
# Plot examples of EUROSTAT values versus each other or versus COVID numbers

fig, ax = plt.subplots(figsize = (13,8))

ax.bar(df_Eurostat["Country"],
       df_Eurostat["Confirmed"],
       color = 'yellow');

#ax.bar(df_Eurostat["Country"],
#       df_Eurostat["Confirmed"],
#       color = 'b');

ax.bar(df_Eurostat["Country"],
       df_Eurostat["total_nights_spent_hotels_2018"],
       color = 'black');


#ax.bar(df_Eurostat["Country"],
#       df_Eurostat["air_transport_passengers_2018"],
#       color = 'orange');



# ax.bar(df_Eurostat["Country"],
#        df_Eurostat["population_density_2018"],
#        color = 'purple');



#ax.bar(df_Eurostat["Country"],
#       df_Eurostat["gdp_per_head_2018"],
#       color = 'pink');




ax.tick_params(labelrotation=90)
ax.set_title("Eurostat values")
ax.set_ylabel("Relevant Values")
ax.set_frame_on(False)

plt.axhline(y=1, xmin=0.0, xmax=1, label = "high: 0.8-1", linewidth=1, color = 'g', );
plt.axhline(y=.8, xmin=0.0, xmax=1, label = "middle: 0.5-0.8", linewidth=1, color = 'b', );
plt.axhline(y=.5, xmin=0.0, xmax=1, label = "low: 0.0-0.5", linewidth=1, color = 'r', );

plt.legend(loc="upper left");

# %%
# Here comes the script of Thomas to for his plots

# %%
# Further Information on How Data was obtained from EUROSTST:

# %%
Eurostat_title =  "Tourism"
json_RQST = 'tin00173?precision=1&unit=PC&accommod=BEDPL&shortLabel=1'

#Eurostat_title =  "Eurostat population density 2018"
#json_RQST = "tps00003?unit=PER_KM2&precision=1&time=2018"

#Eurostat_title =  "Eurostat air transport passengers 2018"
#json_RQST = "ttr00012?tra_meas=PAS_CRD&precision=1&tra_cov=TOTAL&schedule=TOT&unit=PAS&time=2018"

#Eurostat_title =  "Eurostat gdp/head 2018"
#json_RQST = "nama_10_pc?na_item=B1GQ&precision=1&unit=CLV10_EUR_HAB&time=2018"

#Eurostat_title =  "Eurostat health euro expenditure per capita and totals 2017"
#json_RQST = "tps00207?precision=1&unit=EUR_HAB&unit=MIO_EUR&unit=PC_GDP&icha11_hc=TOT_HC&time=2017"

#Eurostat_title = "Eurostat total nights spent by residents/non residents 2018"
#json_RQST = "tin00175?c_resid=FOR&c_resid=NAT&c_resid=TOTAL&precision=1&unit=NR&time=2018&nace_r2=I551-I553"

#Eurostat_title = "Eurostat total deaths by pnomonia 2016"
#json_RQST = "tps00128?precision=1&sex=F&sex=M&sex=T&unit=RT&time=2016&age=TOTAL&icd10=J12-J18"

#Eurostat_title = "Eurostat Standardised death rate due to chronic diseases by sex"
#json_RQST = "sdg_03_40?sex=F&sex=M&sex=T&precision=1&time=2016"

#Eurostat_title = "Eurostat Total Population in January1 st 2018"
#json_RQST = "proj_18np?precision=1&age=TOTAL"

#Eurostat_title = "Eurostat # of practising physicians per 100k inhabitants 2017"
#json_RQST = "tps00044?precision=1&isco08=OC221&unit=P_HTHAB&wstatus=PRACT&time=2017"

#Eurostat_title =  "Eurostat Share of people with good or very good perceived health by sex above 16 2019"
#json_RQST = "sdg_03_20?precision=1&sex=F&sex=M&sex=T&unit=PC&quantile=TOTAL&time=2019&age=Y_GE16&levels=VG_G"


base = "http://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/"
url = base + json_RQST

# %%
# Function to extract Dataframes fr 


def eurostat(url):
    from pyjstat import pyjstat
    from collections import OrderedDict
    # read from json-stat
    dataset = pyjstat.Dataset.read(url)
    # write to dataframe
    df = dataset.write('dataframe')
    return df
    #example from query builder    

df = eurostat(url)


#### Display dataset ##########
print ("Dataset for" , Eurostat_title)    
df
# Out:
# Dataset for Tourism
#       accommod        unit                                                geo  \
# 0    Bedplaces  Percentage                                            Austria
# 1    Bedplaces  Percentage                                            Austria
# 2    Bedplaces  Percentage                                            Austria
# 3    Bedplaces  Percentage                                            Austria
# 4    Bedplaces  Percentage                                            Austria
# ..         ...         ...                                                ...
# 475  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 476  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 477  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 478  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 479  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
#
#         time  value
# 0    2019M03   53.4
# 1    2019M04   34.8
# 2    2019M05   33.5
# 3    2019M06   48.3
# 4    2019M07   59.3
# ..       ...    ...
# 475  2019M10   15.8
# 476  2019M11   15.7
# 477  2019M12   15.5
# 478  2020M01    NaN
# 479  2020M02    NaN
#
# [480 rows x 5 columns]
