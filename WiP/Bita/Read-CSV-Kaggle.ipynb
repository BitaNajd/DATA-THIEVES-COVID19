# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
covdat = pd.read_csv('../module1-porjekt/data-kaggle/covid_19_data.csv')

# %%
covdat.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
posts_subset = covdat[['ObservationDate', 'Province/State', 'Confirmed', 'Deaths' ,'Recovered']]

# %%
posts_subset.head()
# Out:
#   ObservationDate Province/State  Confirmed  Deaths  Recovered
# 0      01/22/2020          Anhui        1.0     0.0        0.0
# 1      01/22/2020        Beijing       14.0     0.0        0.0
# 2      01/22/2020      Chongqing        6.0     0.0        0.0
# 3      01/22/2020         Fujian        1.0     0.0        0.0
# 4      01/22/2020          Gansu        0.0     0.0        0.0

# %%
confirmed = covdat[covdat['Confirmed']==14]

# %%
confirmed
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 1          2      01/22/2020        Beijing  Mainland China
# 189      190      01/26/2020        Tianjin  Mainland China
# 238      239      01/27/2020          Gansu  Mainland China
# 305      306      01/28/2020            NaN        Thailand
# 357      358      01/29/2020            NaN        Thailand
# ...      ...             ...            ...             ...
# 12386  12387      04/06/2020            NaN     Saint Lucia
# 12659  12660      04/07/2020            NaN            Laos
# 12662  12663      04/07/2020            NaN         Liberia
# 12706  12707      04/07/2020            NaN     Saint Lucia
# 12724  12725      04/07/2020            NaN           Sudan
#
#                Last Update  Confirmed  Deaths  Recovered
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 189          1/26/20 16:00       14.0     0.0        0.0
# 238          1/27/20 23:59       14.0     0.0        0.0
# ...

# %%
Germany = covdat[covdat['Country/Region']=="Germany"]

# %%
#NewYork = covdat[covdat['Province/State']=="New-york"]
NewYork = covdat["Indexes"]= covdat["Province/State"].str.find('newyork')

# %%
NewYork
# Out:
# 0       -1.0
# 1       -1.0
# 2       -1.0
# 3       -1.0
# 4       -1.0
#         ...
# 12884   -1.0
# 12885   -1.0
# 12886   -1.0
# 12887   -1.0
# 12888   -1.0
# Name: Province/State, Length: 12889, dtype: float64

# %%
Germany
# Out:
#          SNo ObservationDate Province/State Country/Region  \
# 318      319      01/28/2020        Bavaria        Germany
# 370      371      01/29/2020        Bavaria        Germany
# 426      427      01/30/2020        Bavaria        Germany
# 471      472      01/31/2020        Bavaria        Germany
# 530      531      02/01/2020            NaN        Germany
# ...      ...             ...            ...            ...
# 11360  11361      04/03/2020            NaN        Germany
# 11675  11676      04/04/2020            NaN        Germany
# 11991  11992      04/05/2020            NaN        Germany
# 12310  12311      04/06/2020            NaN        Germany
# 12630  12631      04/07/2020            NaN        Germany
#
#                Last Update  Confirmed  Deaths  Recovered
# 318          1/28/20 23:00        4.0     0.0        0.0
# 370          1/29/20 19:30        4.0     0.0        0.0
# 426          1/30/20 16:00        4.0     0.0        0.0
# ...

# %%
Germany.head()
# Out:
#      SNo ObservationDate Province/State Country/Region      Last Update  \
# 318  319      01/28/2020        Bavaria        Germany    1/28/20 23:00
# 370  371      01/29/2020        Bavaria        Germany    1/29/20 19:30
# 426  427      01/30/2020        Bavaria        Germany    1/30/20 16:00
# 471  472      01/31/2020        Bavaria        Germany  1/31/2020 23:59
# 530  531      02/01/2020            NaN        Germany   2/1/2020 18:33
#
#      Confirmed  Deaths  Recovered
# 318        4.0     0.0        0.0
# 370        4.0     0.0        0.0
# 426        4.0     0.0        0.0
# 471        5.0     0.0        0.0
# 530        8.0     0.0        0.0

# %%
Germany.head()

# %%
Germany.head(-5)
# Out:
#          SNo ObservationDate Province/State Country/Region  \
# 318      319      01/28/2020        Bavaria        Germany
# 370      371      01/29/2020        Bavaria        Germany
# 426      427      01/30/2020        Bavaria        Germany
# 471      472      01/31/2020        Bavaria        Germany
# 530      531      02/01/2020            NaN        Germany
# ...      ...             ...            ...            ...
# 9794    9795      03/29/2020            NaN        Germany
# 10106  10107      03/30/2020            NaN        Germany
# 10419  10420      03/31/2020            NaN        Germany
# 10732  10733      04/01/2020            NaN        Germany
# 11045  11046      04/02/2020            NaN        Germany
#
#                Last Update  Confirmed  Deaths  Recovered
# 318          1/28/20 23:00        4.0     0.0        0.0
# 370          1/29/20 19:30        4.0     0.0        0.0
# 426          1/30/20 16:00        4.0     0.0        0.0
# ...

# %%
#x = Germany.ObservationDate
#y = Germany.Confirmed
#Germany.plot(x='col_name_1', y='col_name_2', style='o')
plt.scatter(Germany['ObservationDate'], Germany['Confirmed'])

# %%
(covdat
 .loc[covdat['Country/Region']=="Germany"]
 .groupby("ObservationDate")
)

# %%
covdat2 = (covdat
 .loc[covdat['Country/Region']=="Germany"]
 .groupby("ObservationDate")
)

# %%
covdat2.head()
# Out:
#          SNo ObservationDate Province/State Country/Region  \
# 318      319      01/28/2020        Bavaria        Germany
# 370      371      01/29/2020        Bavaria        Germany
# 426      427      01/30/2020        Bavaria        Germany
# 471      472      01/31/2020        Bavaria        Germany
# 530      531      02/01/2020            NaN        Germany
# ...      ...             ...            ...            ...
# 11360  11361      04/03/2020            NaN        Germany
# 11675  11676      04/04/2020            NaN        Germany
# 11991  11992      04/05/2020            NaN        Germany
# 12310  12311      04/06/2020            NaN        Germany
# 12630  12631      04/07/2020            NaN        Germany
#
#                Last Update  Confirmed  Deaths  Recovered
# 318          1/28/20 23:00        4.0     0.0        0.0
# 370          1/29/20 19:30        4.0     0.0        0.0
# 426          1/30/20 16:00        4.0     0.0        0.0
# ...

# %%
(covdat
 .loc[covdat['Country/Region']=="Germany"]
 .groupby("ObservationDate")
)

# %%
(df
 .loc[df["order_status"] == "delivered"]
 .groupby("month_id")
 .agg({"price": "sum"})
 .rename(columns={"price": "revenue"})).plot();
