# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
covdat_Bund = pd.read_csv('../module1-porjekt/data-RKI/RKI_Corona_Bundesländer.csv')

# %%
covdat_Bund.head()
# Out:
#    OBJECTID_1  LAN_ew_AGS           LAN_ew_GEN            LAN_ew_BEZ  \
# 0           1           1   Schleswig-Holstein                  Land
# 1           2           2              Hamburg  Freie und Hansestadt
# 2           3           3        Niedersachsen                  Land
# 3           4           4               Bremen      Freie Hansestadt
# 4           5           5  Nordrhein-Westfalen                  Land
#
#    LAN_ew_EWZ  OBJECTID  Fallzahl            Aktualisierung  AGS_TXT  \
# 0     2889821        15      1827  2020-04-07T22:00:00.000Z        1
# 1     1830584         6      3165  2020-04-07T22:00:00.000Z        2
# 2     7962775         9      6385  2020-04-07T22:00:00.000Z        3
# 3      681032         5       424  2020-04-07T22:00:00.000Z        4
# 4    17912134        10     20929  2020-04-07T22:00:00.000Z        5
#
#                                GlobalID  faelle_100000_EW   Shape__Area  \
# ...

# %%
covdat_Land = pd.read_csv('../module1-porjekt/data-RKI/RKI_Corona_Landkreise.csv')

# %%
covdat_Land
# Out:
#      OBJECTID  ADE   GF  BSG     RS     AGS        SDV_RS  \
# 0           1  4.0  4.0  1.0   1001  1001.0  1.001000e+10
# 1           2  4.0  4.0  1.0   1002  1002.0  1.002000e+10
# 2           3  4.0  4.0  1.0   1003  1003.0  1.003000e+10
# 3           4  4.0  4.0  1.0   1004  1004.0  1.004000e+10
# 4           5  4.0  4.0  1.0   1051  1051.0  1.051004e+10
# ..        ...  ...  ...  ...    ...     ...           ...
# 407       411  NaN  NaN  NaN  11005     NaN           NaN
# 408       412  NaN  NaN  NaN  11006     NaN           NaN
# 409       413  NaN  NaN  NaN  11001     NaN           NaN
# 410       414  NaN  NaN  NaN  11002     NaN           NaN
# 411       415  NaN  NaN  NaN  11007     NaN           NaN
#
#                                  GEN               BEZ   IBZ  ... cases  \
# 0                          Flensburg  Kreisfreie Stadt  40.0  ...    30
# 1                               Kiel  Kreisfreie Stadt  40.0  ...   171
# ...

# %%
plt.scatter(G=covdat_Land['ObservationDate'], covdat_Land['Confirmed'])
# Out:
#   File "<ipython-input-19-cddafa75a75f>", line 1
#     plt.scatter(G=covdat_Land['ObservationDate'], covdat_Land['Confirmed'])
#                                                  ^
# SyntaxError: positional argument follows keyword argument
