# %%
import pandas as pd
import datetime
import re
import requests
import bs4
import matplotlib.pyplot as plt
#import matplotlib

# %%
df_who = pd.read_json (r'data-who/covidwho.json')

# %%
df_who.head()
# Out:
#        Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 0  Afghanistan          AF  33.94  67.71          0       0          0
# 1  Afghanistan          AF  33.94  67.71          0       0          0
# 2  Afghanistan          AF  33.94  67.71          0       0          0
# 3  Afghanistan          AF  33.94  67.71          0       0          0
# 4  Afghanistan          AF  33.94  67.71          0       0          0
#
#    Active                      Date                            LocationID  \
# 0       0 2020-01-22 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 1       0 2020-01-23 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 2       0 2020-01-24 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 3       0 2020-01-25 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
# 4       0 2020-01-26 00:00:00+00:00  828ca7f3-144f-4732-b659-a60f97755626
#
#   Province City CityCode
# 0      NaN  NaN      NaN
# 1      NaN  NaN      NaN
# ...

# %%
df_who_Germany = df_who[df_who['Country'] =="Germany"]
#NewYork = covdat["Indexes"]= covdat["Province/State"].str.find('newyork')

# %%
df_who_Germany
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 9629  Germany          DE  51.17  10.45          0       0          0       0
# 9630  Germany          DE  51.17  10.45          0       0          0       0
# 9631  Germany          DE  51.17  10.45          0       0          0       0
# 9632  Germany          DE  51.17  10.45          0       0          0       0
# 9633  Germany          DE  51.17  10.45          0       0          0       0
# ...       ...         ...    ...    ...        ...     ...        ...     ...
# 9701  Germany          DE  51.17  10.45      91159    1275      24575       0
# 9702  Germany          DE  51.17  10.45      96092    1444      26400       0
# 9703  Germany          DE  51.17  10.45     100123    1584      28700       0
# 9704  Germany          DE  51.17  10.45     103374    1810      28700       0
# 9705  Germany          DE  51.17  10.45     107663    2016      36081       0
#
# ...

# %%
plt.scatter(df_who_Germany['Date'], df_who_Germany['Deaths'])

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax.plot(df_who_Germany['Date'],
        df_who_Germany['Deaths'],
        color="g");
ax.set_title("Deaths");
#ax.set_xlim((pd.to_datetime("2017-01-01"), pd.to_datetime("2017-12-01")));
#ax.set_ylim((100000,1000000));
ax.spines["top"].set_visible(False);
ax.spines["right"].set_visible(False);
#ax.set_facecolor("r");

# %%
df_who_Germany = df_who[df_who['Country'] =="Germany"]
df_who_Italy = df_who[df_who['Country'] =="Italy"]
df_who_Spain = df_who[df_who['Country'] =="Spain"]
#plt.scatter(df_who_Germany['Date'], df_who_Germany['Deaths'],df_who_Italy['Deaths'],df_who_Spain['Deaths'])



#df = pd.DataFrame(np.random.randn(100, 6), columns=['a', 'b', 'c', 'd', 'e', 'f'])

c = df_who_Germany['Date'],
c


#ax1 = df_who_Germany['Date'].plot(kind='scatter', x='df_who_Germany['Date']', y='b', color='r')    
#ax2 = df_who_Italy.plot(kind='scatter', x='c', y='d', color='g', ax=ax1)    
#ax3 = df_who_Spain.plot(kind='scatter', x='e', y='f', color='b', ax=ax1)

#print(ax1 == ax2 == ax3)  # True
# Out:
# (9629   2020-01-22 00:00:00+00:00
#  9630   2020-01-23 00:00:00+00:00
#  9631   2020-01-24 00:00:00+00:00
#  9632   2020-01-25 00:00:00+00:00
#  9633   2020-01-26 00:00:00+00:00
#                    ...
#  9701   2020-04-03 00:00:00+00:00
#  9702   2020-04-04 00:00:00+00:00
#  9703   2020-04-05 00:00:00+00:00
#  9704   2020-04-06 00:00:00+00:00
#  9705   2020-04-07 00:00:00+00:00
#  Name: Date, Length: 77, dtype: datetime64[ns, UTC],)

# %%
df3 = df_who.groupby('Date')

# %%
df3.head()
# Out:
#          Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 0    Afghanistan          AF  33.94  67.71          0       0          0
# 1    Afghanistan          AF  33.94  67.71          0       0          0
# 2    Afghanistan          AF  33.94  67.71          0       0          0
# 3    Afghanistan          AF  33.94  67.71          0       0          0
# 4    Afghanistan          AF  33.94  67.71          0       0          0
# ..           ...         ...    ...    ...        ...     ...        ...
# 380       Angola          AO -11.20  17.87          8       2          1
# 381       Angola          AO -11.20  17.87         10       2          2
# 382       Angola          AO -11.20  17.87         14       2          2
# 383       Angola          AO -11.20  17.87         16       2          2
# 384       Angola          AO -11.20  17.87         17       2          2
#
#      Active                      Date                            LocationID  \
# ...

# %%
#df_who.loc["Germany"]
#rowData = df_who.Country.loc[ ['Germany' , 'Italy'] , : ]
#df_who.Country.head()
#rowData = df_who.Country.loc[ 'Germany' ,]
df_who[df_who['Country'].str.contains('Germany')]
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 9629  Germany          DE  51.17  10.45          0       0          0       0
# 9630  Germany          DE  51.17  10.45          0       0          0       0
# 9631  Germany          DE  51.17  10.45          0       0          0       0
# 9632  Germany          DE  51.17  10.45          0       0          0       0
# 9633  Germany          DE  51.17  10.45          0       0          0       0
# ...       ...         ...    ...    ...        ...     ...        ...     ...
# 9701  Germany          DE  51.17  10.45      91159    1275      24575       0
# 9702  Germany          DE  51.17  10.45      96092    1444      26400       0
# 9703  Germany          DE  51.17  10.45     100123    1584      28700       0
# 9704  Germany          DE  51.17  10.45     103374    1810      28700       0
# 9705  Germany          DE  51.17  10.45     107663    2016      36081       0
#
# ...

# %%
#df_who[df_who['Country'].str.contains('Germany')]
df_who_Germany.loc[df_who_Germany['Date'].idxmax()]
# Out:
# Country                                     Germany
# CountryCode                                      DE
# Lat                                           51.17
# Lon                                           10.45
# Confirmed                                    107663
# Deaths                                         2016
# Recovered                                     36081
# Active                                            0
# Date                      2020-04-07 00:00:00+00:00
# LocationID     f770bd88-1a35-4430-bdbc-be3c62afc16b
# Province                                        NaN
# City                                            NaN
# CityCode                                        NaN
# Name: 9705, dtype: object

# %%
df_who.sort_values('Date', ascending=False).drop_duplicates(['Country'])
# Out:
#                          Country CountryCode    Lat     Lon  Confirmed  \
# 263476                  Zimbabwe          ZW -19.02   29.15         11
# 261330  United States of America          US  32.59  -82.30          3
# 9859                      Greece          GR  39.07   21.82       1832
# 4157                        Chad          TD  15.45   18.73         10
# 9936                     Grenada          GD  12.26  -61.60         12
# ...                          ...         ...    ...     ...        ...
# 15172                       Peru          PE  -9.19  -75.02       2954
# 18178                     Uganda          UG   1.37   32.29         52
# 11630              Korea (South)          KR  35.91  127.77      10331
# 12169                      Libya          LY  26.34   17.23         20
# 2463           Brunei Darussalam          BN   4.54  114.73        135
#
#         Deaths  Recovered  Active                      Date  \
# ...

# %%
#df2 = df_who.loc[df_who["Country"] == "Germany"].groupby("Date").agg({"Confirmed": "max"}).rename(columns={"Confirmed": "max"});
df2 = df_who.loc[df_who["Country"] == "Germany"].groupby("Date")


df2.head()


#(df_who
# .loc[df_who["Country"] == "Germany"]
# .groupby("Date")
# .agg({"Confirmed": "max"})
# .rename(columns={"Confirmed": "max"})).plot();

#(df
# .loc[df["order_status"] == "delivered"]
# .groupby("month_id")
# .agg({"price": "sum"})
# .rename(columns={"price": "revenue"})).plot();
# Out:
#       Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  Active  \
# 9629  Germany          DE  51.17  10.45          0       0          0       0
# 9630  Germany          DE  51.17  10.45          0       0          0       0
# 9631  Germany          DE  51.17  10.45          0       0          0       0
# 9632  Germany          DE  51.17  10.45          0       0          0       0
# 9633  Germany          DE  51.17  10.45          0       0          0       0
# ...       ...         ...    ...    ...        ...     ...        ...     ...
# 9701  Germany          DE  51.17  10.45      91159    1275      24575       0
# 9702  Germany          DE  51.17  10.45      96092    1444      26400       0
# 9703  Germany          DE  51.17  10.45     100123    1584      28700       0
# 9704  Germany          DE  51.17  10.45     103374    1810      28700       0
# 9705  Germany          DE  51.17  10.45     107663    2016      36081       0
#
# ...

# %%
df_countries= df_who.groupby('Country')

# %%
df_countries

# %%
df_countries.head()
# Out:
#             Country CountryCode    Lat    Lon  Confirmed  Deaths  Recovered  \
# 0       Afghanistan          AF  33.94  67.71          0       0          0
# 1       Afghanistan          AF  33.94  67.71          0       0          0
# 2       Afghanistan          AF  33.94  67.71          0       0          0
# 3       Afghanistan          AF  33.94  67.71          0       0          0
# 4       Afghanistan          AF  33.94  67.71          0       0          0
# ...             ...         ...    ...    ...        ...     ...        ...
# 263400     Zimbabwe          ZW -19.02  29.15          0       0          0
# 263401     Zimbabwe          ZW -19.02  29.15          0       0          0
# 263402     Zimbabwe          ZW -19.02  29.15          0       0          0
# 263403     Zimbabwe          ZW -19.02  29.15          0       0          0
# 263404     Zimbabwe          ZW -19.02  29.15          0       0          0
#
#         Active                      Date  \
# ...

# %%
df_countries.agg({'Confirmed':'max'})
# Out:
#                                  Confirmed
# Country
# Afghanistan                            423
# Albania                                383
# Algeria                               1468
# Andorra                                545
# Angola                                  17
# ...                                    ...
# Venezuela (Bolivarian Republic)        165
# Viet Nam                               249
# Western Sahara                           4
# Zambia                                  39
# Zimbabwe                                11
#
# [181 rows x 1 columns]

# %%
df2=df_countries.agg({'Confirmed':'max'})

# %%
df2
# Out:
#                                  Confirmed
# Country
# Afghanistan                            423
# Albania                                383
# Algeria                               1468
# Andorra                                545
# Angola                                  17
# ...                                    ...
# Venezuela (Bolivarian Republic)        165
# Viet Nam                               249
# Western Sahara                           4
# Zambia                                  39
# Zimbabwe                                11
#
# [181 rows x 1 columns]

# %%
df2
# Out:
#                                  Confirmed
# Country
# Afghanistan                            423
# Albania                                383
# Algeria                               1468
# Andorra                                545
# Angola                                  17
# ...                                    ...
# Venezuela (Bolivarian Republic)        165
# Viet Nam                               249
# Western Sahara                           4
# Zambia                                  39
# Zimbabwe                                11
#
# [181 rows x 1 columns]

# %%
data.groupby('prime_genre', as_index=False).agg({'price': 'mean'}).sort_values('price', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-fa11ea0e09a9> in <module>
# ----> 1 data.groupby('prime_genre', as_index=False).agg({'price': 'mean'}).sort_values('price', ascending=False)
#
# NameError: name 'data' is not defined

# %%
def eurostat(url):
    from pyjstat import pyjstat
    from collections import OrderedDict
    
    # read from json-stat
    dataset = pyjstat.Dataset.read(url)
    
    # write to dataframe
    df = dataset.write('dataframe')
    
    return df

#example from query builder
url = 'http://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/tgs00045?precision=1&unit=THS_HD&animals=A2300F'

# %%
url = 'http://ec.europa.eu/eurostat/wdds/rest/data/v2.1/json/en/tin00173?precision=1&unit=PC&accommod=BEDPL&shortLabel=1'

# %%
eurostat(url)
# Out:
#       accommod        unit                                                geo  \
# 0    Bedplaces  Percentage                                            Austria
# 1    Bedplaces  Percentage                                            Austria
# 2    Bedplaces  Percentage                                            Austria
# 3    Bedplaces  Percentage                                            Austria
# 4    Bedplaces  Percentage                                            Austria
# ..         ...         ...                                                ...
# 475  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 476  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 477  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 478  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 479  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
#
#         time  value
# ...

# %%
tourism = eurostat(url)

# %%
type(tourism)
# Out:
# pandas.core.frame.DataFrame

# %%
tourism.groupby("value").agg({"value":"sum"})
# Out:
#        value
# value
# 11.1    11.1
# 12.7    12.7
# 14.0    14.0
# 14.3    14.3
# 15.5    15.5
# ...      ...
# 87.0    87.0
# 87.7    87.7
# 88.4    88.4
# 93.2    93.2
# 98.0    98.0
#
# [325 rows x 1 columns]

# %%
tourism
# Out:
#       accommod        unit                                                geo  \
# 0    Bedplaces  Percentage                                            Austria
# 1    Bedplaces  Percentage                                            Austria
# 2    Bedplaces  Percentage                                            Austria
# 3    Bedplaces  Percentage                                            Austria
# 4    Bedplaces  Percentage                                            Austria
# ..         ...         ...                                                ...
# 475  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 476  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 477  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 478  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
# 479  Bedplaces  Percentage  Kosovo (under United Nations Security Council ...
#
#         time  value
# ...

# %%
tourism[tourism['geo']=="Austria"]
# Out:
#      accommod        unit      geo     time  value
# 0   Bedplaces  Percentage  Austria  2019M03   53.4
# 1   Bedplaces  Percentage  Austria  2019M04   34.8
# 2   Bedplaces  Percentage  Austria  2019M05   33.5
# 3   Bedplaces  Percentage  Austria  2019M06   48.3
# 4   Bedplaces  Percentage  Austria  2019M07   59.3
# 5   Bedplaces  Percentage  Austria  2019M08   64.6
# 6   Bedplaces  Percentage  Austria  2019M09   46.1
# 7   Bedplaces  Percentage  Austria  2019M10   35.2
# 8   Bedplaces  Percentage  Austria  2019M11   29.9
# 9   Bedplaces  Percentage  Austria  2019M12   45.3
# 10  Bedplaces  Percentage  Austria  2020M01    NaN
# 11  Bedplaces  Percentage  Austria  2020M02    NaN

# %%
tourism[tourism['geo']=="Slovenia"]
# Out:
#       accommod        unit       geo     time  value
# 432  Bedplaces  Percentage  Slovenia  2019M03  35.10
# 433  Bedplaces  Percentage  Slovenia  2019M04  42.70
# 434  Bedplaces  Percentage  Slovenia  2019M05  43.05
# 435  Bedplaces  Percentage  Slovenia  2019M06  50.80
# 436  Bedplaces  Percentage  Slovenia  2019M07    NaN
# 437  Bedplaces  Percentage  Slovenia  2019M08  69.10
# 438  Bedplaces  Percentage  Slovenia  2019M09  48.30
# 439  Bedplaces  Percentage  Slovenia  2019M10  41.37
# 440  Bedplaces  Percentage  Slovenia  2019M11  32.83
# 441  Bedplaces  Percentage  Slovenia  2019M12  32.99
# 442  Bedplaces  Percentage  Slovenia  2020M01  33.34
# 443  Bedplaces  Percentage  Slovenia  2020M02    NaN

# %%
tourism[tourism['geo']=="Italy"]
# Out:
#       accommod        unit    geo     time  value
# 252  Bedplaces  Percentage  Italy  2019M03   41.6
# 253  Bedplaces  Percentage  Italy  2019M04   44.7
# 254  Bedplaces  Percentage  Italy  2019M05   40.7
# 255  Bedplaces  Percentage  Italy  2019M06   55.8
# 256  Bedplaces  Percentage  Italy  2019M07   68.7
# 257  Bedplaces  Percentage  Italy  2019M08   75.3
# 258  Bedplaces  Percentage  Italy  2019M09   56.5
# 259  Bedplaces  Percentage  Italy  2019M10   48.3
# 260  Bedplaces  Percentage  Italy  2019M11   37.1
# 261  Bedplaces  Percentage  Italy  2019M12   38.5
# 262  Bedplaces  Percentage  Italy  2020M01   42.6
# 263  Bedplaces  Percentage  Italy  2020M02    NaN

# %%
tourism_March = tourism[tourism['time']=="2019M03"]
tourism_March
# Out:
#       accommod        unit                                                geo  \
# 0    Bedplaces  Percentage                                            Austria
# 12   Bedplaces  Percentage                                            Belgium
# 24   Bedplaces  Percentage                                           Bulgaria
# 36   Bedplaces  Percentage                                        Switzerland
# 48   Bedplaces  Percentage                                             Cyprus
# 60   Bedplaces  Percentage                                            Czechia
# 72   Bedplaces  Percentage   Germany (until 1990 former territory of the FRG)
# 84   Bedplaces  Percentage                                            Denmark
# 96   Bedplaces  Percentage  Euro area (EA11-1999, EA12-2001, EA13-2007, EA...
# 108  Bedplaces  Percentage                                            Estonia
# 120  Bedplaces  Percentage                                             Greece
# ...

# %%
# str.contain is better than match
tourism_March[tourism_March['geo'].str.contains("Germany")]
# Out:
#      accommod        unit                                               geo  \
# 72  Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
#
#        time  value
# 72  2019M03  39.91

# %%
top_10_cats = (tourism_March
               .sort_values("value", ascending=False)
               .reset_index()
               .head(10))

# %%
type(top_10_cats)
# Out:
# pandas.core.frame.DataFrame

# %%
fig, ax = plt.subplots(figsize=(8,5))

ax.bar(top_10_cats["geo"],
      top_10_cats["value"],
       color='r');
ax.tick_params(labelrotation=90);
ax.set_title("Top Toursim");
ax.set_frame_on(False);

# %%
countries_sel = ["Germany","Italy","Spain","Malta"]

# %%
#tourism_March[(tourism_March[['geo']].values == ["Germany"]).all(1)]
tourism_March[tourism_March.geo.str.contains('|'.join(countries_sel))]
# Out:
#       accommod        unit                                               geo  \
# 72   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 132  Bedplaces  Percentage                                             Spain
# 252  Bedplaces  Percentage                                             Italy
# 336  Bedplaces  Percentage                                             Malta
#
#         time  value
# 72   2019M03  39.91
# 132  2019M03  53.51
# 252  2019M03  41.60
# 336  2019M03  56.20

# %%
def Eurostat_rating (dataset, countries_sel):
    
    Eurostat_rating_sel = dataset[dataset.geo.str.contains('|'.join(countries_sel))]
    return Eurostat_rating_sel
    




def Eurostat_rating_March (dataset, countries_sel):
    
    dataset_March = dataset[dataset['time']=="2019M03"]
    Eurostat_rating_sel_March = dataset_March[dataset_March.geo.str.contains('|'.join(countries_sel))]
    return Eurostat_rating_sel_March

# %%
Eurostat_rating(tourism, countries_sel)
# Out:
#       accommod        unit                                               geo  \
# 72   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 73   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 74   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 75   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 76   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 77   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 78   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 79   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 80   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 81   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 82   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# ...

# %%
Eurostat_rating_March(tourism, countries_sel)
# Out:
#       accommod        unit                                               geo  \
# 72   Bedplaces  Percentage  Germany (until 1990 former territory of the FRG)
# 132  Bedplaces  Percentage                                             Spain
# 252  Bedplaces  Percentage                                             Italy
# 336  Bedplaces  Percentage                                             Malta
#
#         time  value
# 72   2019M03  39.91
# 132  2019M03  53.51
# 252  2019M03  41.60
# 336  2019M03  56.20

# %%
fig, ax = plt.subplots(figsize=(8,5))

ax.bar(Eurostat_rating_March(tourism, countries_sel)["geo"],
       Eurostat_rating_March(tourism, countries_sel)["value"],
       color='r');
ax.tick_params(labelrotation=90);
ax.set_title("Top selected ones");
ax.set_frame_on(False);
