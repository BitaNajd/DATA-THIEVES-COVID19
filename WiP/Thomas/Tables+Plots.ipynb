# %%
import pandas as pd
import datetime
import re
import requests
import bs4
import matplotlib.pyplot as plt
import seaborn as sns
#import matplotlib
from IPython.display import display, HTML

# %%
df_Eurostat = pd.read_csv("newcovid_deaths_pneumod_chronicdrate.csv")
df_Eurostat.sort_values('Deaths', ascending=False)
df_Eurostat.plot()

# %%
df_Eurostat = pd.read_csv("newcovid_deaths_phys_health_exp.csv")
df_Eurostat.sort_values('Deaths', ascending=False)
df_Eurostat.plot()

# %%
df_Eurostat = pd.read_csv("newcovid_confirmd_hotel_pass_percountry.csv")
df_Eurostat.sort_values('Confirmed', ascending=False)
df_Eurostat.plot()

# %%
df_Eurostat = pd.read_csv("newcovid_deaths_popdens_percountry.csv")
df_Eurostat.sort_values('Confirmed', ascending=False)
df_Eurostat.plot()

# %%
# if you want to plot using pandas methods, don't reset the index. Instead, pandas uses the index as the x-axis
(df
 .loc[df["order_status"] == "delivered"]
 .groupby("month_id")
 .agg({"price": "sum"})
 .rename(columns={"price": "revenue"})).plot();

# %%
passengers_confirmed = (df
               .loc[df["order_status"] == "delivered"]
               .groupby("month_id")
               .agg({"price": "sum"})
               .rename(columns={"price": "revenue"})
               .reset_index())
